# %% [markdown]
# # **Files & Exceptional handling Assignment**

# %% [markdown]
# ## **Theoretical Questions**

# %% [markdown]
# ###**1. What is the difference between interpreted and compiled languages?**
#
# **Answer:**
#
# - **Interpreted (like Python):** Code runs line-by-line using an interpreter. Slower, but easy to test.
#
# - **Compiled (like C++):** Code is converted into machine code before running. Faster, but harder to debug.

# %% [markdown]
# ### **2. What is Exception Handling in Python?**
#
# **Answer:**
#
# Exception handling is how Python deals with errors without stopping the program.

# %%
try:
    a = 10 / 0
except ZeroDivisionError:
    print("Can't divide by zero")
# Out:
# Can't divide by zero

# %% [markdown]
# ### **3. What is the purpose of the finally block in exception handling?**
#
# **Answer:**
#
# The `finally` block always runs, whether there's an error or not. Useful for cleaning up (e.g., closing files).

# %%
f = None  # Initialize f to None
try:
    f = open("data.txt")
except:
    print("Error!")
finally:
    if f is not None: # Check if f is not None before closing
        f.close()
# Out:
# Error!

# %% [markdown]
# ### **4. What is Logging in Python?**
#
# **Answer:**
#
# Logging in Python is a robust and flexible standard library module that provides a system for emitting event messages from your programs. It's a more sophisticated and practical alternative to simply using `print()` statements for debugging and monitoring, especially for larger or production applications.
#
# **Core Purpose:**
#
# The primary purpose of logging is to keep a record of events that occur while your program is running. These events can include:
#
# - **Informational messages:** Confirming that things are working as expected.
#
# - **Warnings:** Indicating that something unexpected happened, or a potential problem is looming, but the software is still working.
#
# - **Errors:** Signifying that the software has encountered a problem and cannot perform a function.
#
# - Critical errors:** Severe problems indicating that the program itself may be unable to continue.
#
# - **Debugging information:** Detailed internal state of the program, useful for developers when diagnosing issues.

# %% [markdown]
# ### **5. What is the significance of the _ _ del_ _ method in Python?**
#
# **Answer:**
#
# This special method is called when an object is `deleted`.

# %%
class A:
    def __del__(self):
        print("Object deleted")

# %% [markdown]
# ### **6. What is the difference between import and from ... import in Python?**
#
# **Answer:**
#
# - `import math` → Use `like math.sqrt(4)`
#
# - `from math import sqrt` → Use like `sqrt(4)`

# %% [markdown]
# ### **7. How can you handle multiple exceptions in Python?**
#
# **Answer:**

# %%
try:
    a = int("abc")
    b = 1 / 0
except ValueError:
    print("Wrong value")
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Wrong value

# %% [markdown]
# ### **8. What is the purpose of the with statement when handling files in Python?**
#
# **Answer:**
#
# The `with` statement in Python is used when handling files to ensure that a file is properly closed after its suite finishes, even if exceptions are raised. It handles the opening and closing of the file automatically.

# %%
with open("my_file.txt", "w") as f:
    f.write("Hello, world!")

# %% [markdown]
# ### **9. What is the difference between multithreading and multiprocessing?**
#
# **Answer:**
#
# - Multithreading:
#
#   - **Defination:** Multiple threads run *within the same process*
#   - **Best for: I/O-bound tasks** (like file handling, API calls)
#   - **Memory Usage:** Threads share the same memory
#   - **Speed:** Faster for lightweight tasks
#   - **Crashes:** One thread crash can affect the whole process
#   - **Global Interpreter Lock (GIL):** Affected by GIL (only one thread runs at a time in CPython)
#   - **Library Used:** `threading` module
#
# - **Multiprocessing:**
#
#   - **Defination:** Multiple **processes run independently**
#   - **Best for: CPU-bound tasks** (like heavy calculations)
#   - **Memory Usage:** Processes have **separate memory**
#   - **Speed:** Better performance for heavy tasks
#   - **Crashes:** Each process is isolated; one crash doesn’t affect others
#   - **Global Interpreter Lock (GIL):** Each process is isolated; one crash doesn’t affect others
#   - **Library Used:** `multiprocessing` module
#
# **Example:**

# %%
# Multirhreading:

import threading

def show():
    for i in range(5):
        print("Thread")

thread1 = threading.Thread(target=show)
thread1.start()
# Out:
# Thread
# Thread
# Thread
# Thread
# Thread

# %%
# Multiprocessing:

import multiprocessing

def show():
    for i in range(5):
        print("Process")

process1 = multiprocessing.Process(target=show)
process1.start()
# Out:
# Process

# %% [markdown]
# **Summary:**
#
# Use **multithreading** when tasks **wait for something** (like downloading, reading files).
#
# Use **multiprocessing** when tasks **need lots of computation power** (like data processing, ML training).

# %% [markdown]
# ### **10. What are the advantages of using logging in a program?**
#
# **Answer:**
#
# Using logging in a program offers several advantages:
#
# - **Debugging:** Provides a detailed history of what happened in the program, making it easier to identify and fix bugs.
#
# - **Monitoring:** Allows you to track the program's behavior in production, identifying potential issues before they become critical.
#
# - **Auditing:** Can be used to record significant events, user actions, or system changes for security or compliance purposes.
#
# - **Problem Diagnosis:** Helps in diagnosing issues in deployed applications without needing to attach a debugger.
#
# - **Separation of Concerns:** Keeps debugging/monitoring output separate from the main program output.
#
# - **Flexibility:** Python's `logging` module offers various levels (DEBUG, INFO, WARNING, ERROR, CRITICAL) and handlers (console, file, network, etc.) to control where and how messages are output.

# %% [markdown]
# ### **11. What is memory management in Python?**
#
# **Answer:**
#
# Memory management in Python involves how Python handles the allocation and deallocation of memory for objects. Key aspects include:
#
# - **Private Heaps:** Python has a private heap where all Python objects and data structures reside. Programmers do not directly control this heap.
#
# - **Automatic Memory Management:** Python uses a combination of techniques for automatic memory management:
#
# - **Reference Counting:** Each object has a reference count, which tracks how many references point to it. When the count drops to zero, the object's memory is deallocated.
#
# - **Garbage Collection (Generational Cyclic Garbage Collector):** This mechanism deals with circular references (where objects refer to each other, preventing their reference counts from ever reaching zero). It periodically identifies and collects these unreachable cycles.
#
# - **Memory Pools:** For smaller objects, Python uses memory pools to allocate memory more efficiently, reducing the overhead of system calls for every small allocation.

# %% [markdown]
# ### **12. What are the basic steps involved in exception handling in Python?**
#
# **Answer:**
#
# The basic steps involved in exception handling in Python are:
#
# 1. `try` **block:** Code that might raise an exception is placed inside the `try` block.
#
# 2. `except` **block(s):** If an exception occurs in the `try` block, the corresponding `except` block is executed. You can have multiple `except` blocks to handle different types of exceptions.
#
# 3. `else` **block (optional):** This block is executed if no exception occurs in the try block.
#
# 4. `finally` **block (optional):** This block is always executed, regardless of whether an exception occurred or not. It's typically used for cleanup operations.
#
# **Syntax:**

# %%
try:
    # Code that might raise an exception
    result = 10 / 0
except ZeroDivisionError:
    # Code to handle ZeroDivisionError
    print("Cannot divide by zero!")
except TypeError:
    # Code to handle TypeError
    print("Invalid type operation!")
else:
    # Code to execute if no exception occurred
    print("Division successful!")
finally:
    # Code that always executes (e.g., cleanup)
    print("Execution complete.")
# Out:
# Cannot divide by zero!
# Execution complete.

# %% [markdown]
# ### **13. Why is memory management important in Python?**
#
# **Answer:**
#
# Memory management is crucial in Python for several reasons:
#
# - **Resource Efficiency:** Efficient memory management prevents programs from consuming excessive amounts of RAM, which can lead to slow performance or even crashes, especially in long-running applications or those handling large datasets.
#
# - **Performance:** Unmanaged memory can lead to memory leaks (memory that is no longer needed but not released), causing the program to slow down over time as it requests more and more memory.
#
# - **Stability:** Proper memory management ensures that memory is allocated and deallocated correctly, preventing segmentation faults or other low-level errors that can destabilize the application.
#
# - **Scalability:** For applications that need to handle a growing number of users or data, efficient memory management is vital for scaling without hitting memory limitations.
#
# - **Automatic Handling:** While Python handles memory automatically, understanding its mechanisms helps developers write code that is memory-efficient and avoid patterns that could inadvertently lead to performance issues related to memory.

# %% [markdown]
# ### **14. What is the role of try and except in exception handling?**
#
# **Answer:**
#
# - `try`: The `try` block encloses the code that is expected to potentially raise an exception. It serves as a "monitor" for errors. If an exception occurs within the `try` block, the execution of the `try` block is immediately stopped, and Python looks for a matching `except` block.
#
# - `except`: The `except` block is responsible for handling specific types of exceptions that might be raised in the corresponding `try` block. When an exception occurs, Python checks if the type of the raised exception matches the type specified in an `except` block. If a match is found, the code within that `except` block is executed, allowing the program to gracefully recover or respond to the error instead of crashing.
#
# In essence, `try` identifies the potential problem area, and `except` provides the solution or alternative action when a problem arises.

# %% [markdown]
# ### **15. How does Python's garbage collection system work?**
# **Answer:**
#
# Python's garbage collection system primarily relies on two mechanisms:
#
# **1. Reference Counting:**
# - This is the primary and most immediate form of garbage collection.
#
# - Every object in Python maintains a count of the number of references pointing to it.
#
# - When an object's reference count drops to zero, it means there are no longer any variables or other objects referring to it.
#
# - At this point, the memory occupied by that object is immediately deallocated and returned to the free list.
#
# - **Limitation:** Reference counting cannot detect and collect objects that are part of a reference cycle. For example, if object A refers to B, and B refers to A, even if there are no external references to A or B, their reference counts will never drop to zero.
#
# **2. Generational Cyclic Garbage Collector:**
# - This is a supplemental garbage collector that runs periodically to address the limitation of reference counting (i.e., collecting circular references).
#
# - It divides objects into "generations" (0, 1, 2, etc.) based on how long they have been alive. Newly created objects start in generation 0.
#
# - Objects that survive a garbage collection cycle are promoted to an older generation. The intuition is that older objects are less likely to be garbage.
#
# - The collector primarily focuses on checking newer generations more frequently, as they are more likely to contain objects that can be collected.
#
# - When it runs, it identifies groups of objects that are mutually referencing each other but are no longer reachable from the root set (e.g., global variables, active stack frames). These unreachable cycles are then collected.
#
# In summary, reference counting handles most object deallocations instantly, while the generational cyclic garbage collector periodically sweeps for and collects objects involved in reference cycles.

# %% [markdown]
# ### **16. What is the purpose of the else block in exception handling?**
#
# **Answer:**
#
# The `else` block in exception handling is an optional part of the `try...except` statement. Its purpose is to contain code that should be executed only if no exception occurs in the `try` block.
#
# It provides a clean way to separate code that is critical for the success of the `try` block from code that should only run after that success is confirmed.
#
# **Example:**

# %%
try:
    file = open("my_data.txt", "r")
    content = file.read()
except FileNotFoundError:
    print("Error: The file was not found.")
else:
    print("File read successfully. Content:")
    print(content)
    file.close() # Only close if successfully opened and read
finally:
    print("Attempted file operation.")
# Out:
# Error: The file was not found.
# Attempted file operation.

# %% [markdown]
# In this example, `file.close()` is placed in `else` because it only makes sense to close the file if it was successfully opened and read. If `FileNotFoundError` occurs, `file` would not be a valid file object to close. The `finally` block could also be used for `file.close()` if `file` was guaranteed to be assigned even in case of an error (e.g., initialized to None beforehand).

# %% [markdown]
# ### **17. What are the common logging levels in Python?**
#
# **Answer:**
#
# Python's `logging` module provides a set of standard logging levels, ordered by increasing severity:
#
# 1. `DEBUG` **(10):** Detailed information, typically of interest only when diagnosing problems.
#
# 2. `INFO` **(20):** Confirmation that things are working as expected.
#
# 3. `WARNING` **(30):** An indication that something unexpected happened, or indicative of some problem in the near future (e.g., 'disk space low'). The software is still working as expected.
#
# 4. `ERROR` **(40):** Due to a more serious problem, the software has not been able to perform some function.
#
# 5. `CRITICAL` **(50):** A serious error, indicating that the program itself may be unable to continue running.
#
# You can set a logging level for your logger, and only messages with that level or higher will be processed.

# %% [markdown]
# ### **18. What is the difference between os.fork() and multiprocessing in Python?**
#
# **Answer:**
#
# While both `os.fork()` and the `multiprocessing` module are used for creating new processes in Python, they represent different levels of abstraction and portability:
#
# - `os.fork()`:
#
#   - **Lower-level:** `os.fork()` is a direct wrapper around the Unix `fork()` system call.
#
#   - **Platform-specific**: It is only available on Unix-like systems (Linux, macOS, BSD). It does not work on Windows.
#
#   - **Process creation:** When `os.fork()` is called, it creates a new child process that is an almost identical copy of the parent process. The child process starts execution from the point where `fork()` was called.
#
#   - **Memory:** The child process initially shares memory with the parent via copy-on-write, meaning pages are copied only when one process modifies them.
#
#   - **Complexity:** Managing communication and synchronization between parent and child processes with `os.fork()` often requires lower-level mechanisms (e.g., pipes, shared memory, semaphores) that you implement manually.
#
# - `multiprocessing` **module:**
#
#   - **Higher-level:** The `multiprocessing` module provides a more abstract and object-oriented API for process management.
#
#   - **Cross-platform:** It works on both Unix-like systems and Windows (on Windows, it often uses `subprocess` under the hood or spawns new Python interpreters).
#
#   - **Process creation:** It provides classes like `Process`, `Pool`, and `Queue` that abstract away the complexities of process creation, communication, and synchronization.
#
#   - **Communication:** It offers built-in high-level mechanisms for inter-process communication (IPC) such as `Queue`, `Pipe`, `Value`, `Array`, and `Manager` for sharing data.
#
#   - **Ease of Use:** Generally easier to use for most multiprocessing needs, especially for complex scenarios or when cross-platform compatibility is required.
#
# **In summary:** `os.fork()` is a fundamental, low-level, Unix-specific function for creating processes. The `multiprocessing` module is a robust, high-level, cross-platform library built on top of `os.fork()` (or similar mechanisms on other OSes) that simplifies concurrent programming with processes. For most Python applications requiring multiprocessing, the `multiprocessing` module is the preferred choice due to its portability and ease of use.

# %% [markdown]
# ### **19. What is the importance of closing a file in Python?**
#
# **Answer:**
#
# Closing a file in Python is critically important for several reasons:
#
# **1.Resource Release:** When you open a file, the operating system allocates resources (like file descriptors/handles) to your program. Closing the file releases these resources, making them available for other parts of your program or other applications. Failing to close files can lead to resource exhaustion, especially in long-running applications or those opening many files.
#
# **2.Data Integrity/Persistence:** When you write to a file, the data is often buffered in memory before being physically written to disk. Closing the file explicitly flushes these buffers, ensuring that all data is written to the file and changes are saved. If a program crashes before a file is closed, data might be lost or corrupted.
#
# **3.Preventing Locks:** On some operating systems, an open file might be locked, preventing other programs or even other parts of your own program from accessing or modifying it. Closing the file releases these locks.
#
# **4.Avoiding Errors:** Reaching the maximum number of open files allowed by the operating system can cause `IOError` or `OSError` exceptions, preventing further file operations. Closing files as soon as they are no longer needed prevents this.
#
# **5.Security:** In some contexts, leaving files open longer than necessary could pose a security risk, especially if the file contains sensitive information.
#
# The `with` statement (as discussed in Q8) is the recommended way to handle files because it automatically ensures that files are closed, even if errors occur, making your code safer and more robust.

# %% [markdown]
# ### **20. What is the difference between file.read() and file.readline() in Python?**
#
# **Answer:**
#
# Both `file.read(`) and `file.readline()` are methods used to read data from a file object, but they differ in how much data they read:
#
# - `file.read(size=-1)`:
#
#   - Reads the entire content of the file as a single string.
#
#   - If an optional `size` argument is provided, it reads at most `size` bytes (or characters for text mode) from the file.
#
#   - After reading, the file pointer is at the end of the file (or after `size` bytes).
#
# **Example:**

# %%
# my_file.txt contains:
# Line 1
# Line 2
with open("my_file.txt", "r") as f:
    content = f.read()
    print(content)
# Output:
# Line 1
# Line 2
# Out:
# Hello, world!

# %% [markdown]
# - file.readline(size=-1):
#
#   - Reads a single line from the file, including the newline character `(\n)` if present, until it encounters a newline or the end of the file.
#
#   - If an optional `size` argument is provided, it reads at most `size` bytes/characters, but it will still stop if a newline is encountered within that `size`.
#
#   - After reading, the file pointer is at the beginning of the next line.
#
# **Example:**

# %%
# my_file.txt contains:
# Line 1
# Line 2
with open("my_file.txt", "r") as f:
    line1 = f.readline()
    line2 = f.readline()
    print(line1, end='') # Use end='' to avoid extra newline from print
    print(line2, end='')
# Output:
# Line 1
# Line 2
# Out:
# Hello, world!

# %% [markdown]
# **When to use which:**
#
# - Use `file.read()` when you need the entire content of a file (e.g., configuration files, small text files) or a specific number of bytes.
#
# - Use `file.readline()` when you want to process a file line by line (e.g., log files, CSV files where you need to parse each row sequentially). Iterating directly over the file object (e.g., `for line in file`:) is generally more efficient for line-by-line processing than calling `readline()` in a loop.

# %% [markdown]
# ### **21. What is the logging module in Python used for?**
#
# **Answer:**
#
# The `logging` module in Python is a powerful and flexible standard library module that provides a framework for emitting log messages from applications. Its primary uses include:
#
# - **Recording Events:** To keep a record of events that occur during the execution of a program, such as program start/end, user actions, data processing steps, or network communications.
#
# - **Debugging and Troubleshooting:** To provide diagnostic information that helps developers understand what went wrong when an error occurs or to track the flow of execution during development.
#
# - **Monitoring and Analysis:** In production environments, logs are crucial for monitoring the health and performance of an application, identifying trends, and performing post-mortem analysis of issues.
#
# - **Auditing and Compliance:** To record significant events for security audits, regulatory compliance, or to track data changes.
#
# - **Separating Output:** To keep informative and debugging messages separate from the program's normal output (e.g., user interface output).
#
# The `logging` module allows you to:
#
# - Define different **logging levels** (DEBUG, INFO, WARNING, ERROR, CRITICAL).
#
# - Send log messages to various **destinations** (console, files, network sockets, email, etc.) using handlers.
#
# - Format log messages with **formatters** to include timestamps, log level, module name, etc.
#
# - Create multiple **loggers** for different parts of your application, allowing for fine-grained control over logging behavior.

# %% [markdown]
# ### **22. What is the os module in Python used for in file handling?**
#
# **Answer:**
#
# The `os` module in Python provides a way of using operating system dependent functionality. In the context of file handling, it is primarily used for:
#
# - **Path Manipulation:**
#
# - `os.path.join()`: To construct platform-independent file paths.
#
# - `os.path.exists()`: To check if a file or directory exists.
#
# - `os.path.isfile()`: To check if a path refers to a regular file.
#
# - `os.path.isdir()`: To check if a path refers to a directory.
#
# - `os.path.basename()`: To get the base name of a path.
#
# - `os.path.dirname()`: To get the directory name of a path.
#
# - `os.path.splitext()`: To split a path into root and extension.
#
# - **Directory Operations:**
#
# - `os.mkdir()`: To create a new directory.
#
# - `os.makedirs()`: To create directories recursively.
#
# - `os.rmdir()`: To remove an empty directory.
#
# - `os.removedirs()`: To remove empty directories recursively.
#
# - `os.listdir()`: To list the contents of a directory.
#
# - `os.chdir()`: To change the current working directory.
#
# - `os.getcwd()`: To get the current working directory.
#
# - **File Operations (beyond basic** `open()` ):
#
# - `os.remove()` / `os.unlink()`: To delete a file.
#
# - `os.rename()`: To rename a file or directory.
#
# - `os.stat()`: To get status information about a file (size, modification time, etc.).
#
# - `os.walk()`: To traverse a directory tree.
#
# While `open()` handles the core reading/writing of file content, the `os` module provides the necessary tools for interacting with the file system itself, managing files and directories, and handling paths in a robust, cross-platform manner.

# %% [markdown]
# ### **23. What are the challenges associated with memory management in Python?**
#
# **Answer:**
#
# Despite Python's automatic memory management, there are still challenges and considerations:
#
# **1. Reference Cycles:** While the garbage collector addresses circular references, they can still consume memory until the collector runs. In performance-critical applications or those dealing with many short-lived objects, this overhead can be noticeable.
#
# **2. Memory Footprint for Large Objects:** Python objects inherently have some overhead. For extremely large datasets or objects (e.g., large lists of small integers, or many small strings), the memory footprint can be larger than in lower-level languages like C++.
#
# **3. Predictability of Garbage Collection:** The exact timing of when the generational garbage collector runs is not always predictable, which can be an issue for real-time systems or applications with strict memory usage constraints.
#
# **4. Immutable Objects:** Immutable types (like strings, tuples, numbers) create new objects every time they are modified. Frequent operations on large immutable objects can lead to temporary memory spikes.
#
# **5. Memory Leaks (Indirect):** While Python prevents true memory leaks in the C sense (where memory is allocated but never freed), "logical" or "indirect" memory leaks can occur. This happens when objects are still referenced (and thus not garbage collected) but are no longer functionally needed by the program (e.g., objects accumulating in a global list that's never cleared).
#
# **6. Global Interpreter Lock (GIL) and Memory:** While not directly a memory management issue, the GIL can sometimes influence how memory is perceived or managed in multi-threaded scenarios, as only one thread can execute Python bytecode at a time.
#
# **7. Debugging Memory Issues:** Identifying the root cause of high memory usage or "logical" leaks can be challenging, often requiring specialized profiling tools.
#
# Developers need to be aware of these challenges to write memory-efficient Python code, especially for applications that are memory-intensive or run for long durations.

# %% [markdown]
# ### **24. How do you raise an exception manually in Python?**
#
# **Answer:**
#
# You raise an exception manually in Python using the `raise` keyword, followed by an instance of an exception class.
#
# **Examples:**
#
# **1. Raising a built-in exception:**

# %%
def get_positive_number(value):
    if value < 0:
        raise ValueError("Input must be a positive number.")
    return value

try:
    print(get_positive_number(5))
    print(get_positive_number(-2))
except ValueError as e:
    print(f"Caught an error: {e}")
# Out:
# 5
# Caught an error: Input must be a positive number.

# %% [markdown]
# **2. Raising a custom exception:**
#
# (First, define your custom exception by inheriting from `Exception` or a more specific built-in exception)

# %%
class MyCustomError(Exception):
    """Custom exception for specific application errors."""
    pass

def check_status(status_code):
    if status_code != 200:
        raise MyCustomError(f"API call failed with status code: {status_code}")
    print("API call successful!")

try:
    check_status(404)
except MyCustomError as e:
    print(f"Custom error caught: {e}")
# Out:
# Custom error caught: API call failed with status code: 404

# %% [markdown]
# When `raise` is executed, the normal flow of the program is interrupted, and Python begins searching for an appropriate `except` block to handle the raised exception. If no matching `excep`t block is found in the current scope, the exception propagates up the call stack until it's caught or the program terminates.

# %% [markdown]
# ### **25. Why is it important to use multithreading in certain applications?**
#
# **Answer:**
#
# Multithreading is important in certain applications primarily for improving responsiveness and resource utilization, especially for I/O-bound tasks. Here's why:
#
# **1. Responsiveness (especially in GUIs):**
# - In graphical user interfaces (GUIs), if a long-running operation (like fetching data from the internet or processing a large file) runs on the main thread, the GUI will "freeze" and become unresponsive.
#
# - By offloading such operations to a separate thread, the main thread remains free to handle user interactions (button clicks, window resizing), keeping the application responsive.
#
# **2. I/O-Bound Operations:**
# - Many applications spend a significant amount of time waiting for I/O operations to complete (e.g., reading/writing to disk, network requests, database queries).
#
# - While one thread is waiting for an I/O operation to finish, other threads can execute useful work. This doesn't involve true parallel execution of CPU-bound code (due to Python's GIL), but it allows the program to "overlap" I/O wait times with CPU computation.
#
# - This improves overall throughput and perceived performance.
#
# **3. Simplicity for Concurrent Tasks:**
# - For tasks that logically run concurrently (e.g., a server handling multiple client connections simultaneously), multithreading can simplify the program's design. Each client connection can be handled by a dedicated thread.
#
# **4. Resource Sharing:**
# - Threads within the same process share the same memory space. This makes data sharing between concurrent tasks relatively straightforward (though requiring careful synchronization to avoid race conditions). This is often simpler than inter-process communication for shared data.
#
# **Important Note on Python's GIL:** While multithreading is beneficial for I/O-bound tasks in Python, it's crucial to remember the Global Interpreter Lock (GIL). The GIL ensures that only one thread can execute Python bytecode at any given time. This means that for CPU-bound tasks (tasks that primarily involve heavy computation and little I/O), multithreading in Python will not lead to true parallel execution on multi-core processors. For CPU-bound parallelism, multiprocessing is the go-to solution.

# %% [markdown]
# # **Practical Questions**

# %% [markdown]
# ### **1. How can you open a file for writing in Python and write a string to it?**
#
# **Answer:**

# %%
# Open a file for writing ('w' mode)
# If the file doesn't exist, it will be created.
# If the file exists, its content will be truncated (emptied).
try:
    with open("my_output.txt", "w") as file:
        file.write("Hello, this is a test string.\n")
        file.write("This is a second line.")
    print("Successfully wrote string to 'my_output.txt'")
except IOError as e:
    print(f"Error writing to file: {e}")
# Out:
# Successfully wrote string to 'my_output.txt'

# %% [markdown]
# ### **2. Write a Python program to read the contents of a file and print each line.**
#
# **Answer:**
#
# You can read a file line by line by iterating directly over the file object.

# %%
# Create a dummy file for demonstration
with open("sample_read.txt", "w") as f:
    f.write("First line of text.\n")
    f.write("Second line here.\n")
    f.write("And the last line.")

# Read the contents of the file line by line
try:
    with open("sample_read.txt", "r") as file:
        print("Contents of 'sample_read.txt':")
        for line in file:
            print(line.strip()) # .strip() removes leading/trailing whitespace, including the newline
except FileNotFoundError:
    print("Error: 'sample_read.txt' not found.")
except IOError as e:
    print(f"Error reading file: {e}")
# Out:
# Contents of 'sample_read.txt':
# First line of text.
# Second line here.
# And the last line.

# %% [markdown]
# ### **3. How would you handle a case where the file doesn't exist while trying to open it for reading?**
#
# **Answer:**
#
# You handle a `FileNotFoundError` using a `try-except` block.

# %%
file_name = "non_existent_file.txt"

try:
    with open(file_name, "r") as file:
        content = file.read()
        print(f"File content:\n{content}")
except FileNotFoundError:
    print(f"Error: The file '{file_name}' does not exist.")
except IOError as e:
    print(f"An I/O error occurred: {e}")
# Out:
# Error: The file 'non_existent_file.txt' does not exist.

# %% [markdown]
# ### **4. Write a Python script that reads from one file and writes its content to another file.**

# %%
source_file = "source.txt"
destination_file = "destination.txt"

# Create a dummy source file
with open(source_file, "w") as f:
    f.write("This is the content from the source file.\n")
    f.write("It will be copied to the destination file.")

try:
    # Open source file for reading
    with open(source_file, "r") as infile:
        content = infile.read()

    # Open destination file for writing (creates/overwrites)
    with open(destination_file, "w") as outfile:
        outfile.write(content)

    print(f"Content successfully copied from {source_file} to {destination_file}")

except FileNotFoundError:
    print(f"Error: Source file {source_file} not found.")
except IOError as e:
    print(f"An I/O error occurred during file operation: {e}")
# Out:
# Content successfully copied from source.txt to destination.txt

# %% [markdown]
# ### **5. How would you catch and handle division by zero error in Python?**
#
# **Answer:**
#
# You use a `try-except` block to catch `ZeroDivisionError`.

# %%
def safe_divide(numerator, denominator):
    try:
        result = numerator / denominator
        print(f"Result of division: {result}")
    except ZeroDivisionError:
        print("Error: Cannot divide by zero!")
    except TypeError: # Good practice to catch other potential errors too
        print("Error: Invalid types for division. Please provide numbers.")
    except Exception as e: # Generic catch-all for unexpected errors
        print(f"An unexpected error occurred: {e}")

safe_divide(10, 2)
safe_divide(5, 0)
safe_divide(10, "a") # Demonstrate TypeError handling
# Out:
# Result of division: 5.0
# Error: Cannot divide by zero!
# Error: Invalid types for division. Please provide numbers.

# %% [markdown]
# ### **6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.**

# %%
import logging

# Configure logging to write ERROR level messages to 'error_log.txt'
logging.basicConfig(filename='error_log.txt', level=logging.ERROR)

try:
    a = 10 / 0  # This will cause a ZeroDivisionError
except ZeroDivisionError:
    # Log an error message when ZeroDivisionError occurs
    logging.error("Tried dividing by zero")
# Out:
# ERROR:root:Tried dividing by zero

# %% [markdown]
# ### **7.How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?**

# %%
import logging

# Configure logging to process messages from DEBUG level onwards.
# By default, messages go to the console.
logging.basicConfig(level=logging.DEBUG)

# Log messages at different severity levels
logging.info("This is an INFO message")
logging.warning("This is a WARNING message")
logging.error("This is an ERROR message")
# Out:
# WARNING:root:This is a WARNING message
# ERROR:root:This is an ERROR message

# %% [markdown]
# ### **8. Write a program to handle a file opening error using exception handling.**

# %%
def open_and_read_file(filename):
    try:
        with open(filename, "r") as file:
            content = file.read()
            print(f"Successfully read '{filename}':\n{content}")
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
    except PermissionError:
        print(f"Error: You do not have permission to access '{filename}'.")
    except IOError as e:
        print(f"An unexpected I/O error occurred while opening '{filename}': {e}")
    except Exception as e:
        print(f"An unknown error occurred: {e}")

# Test cases
print("--- Attempting to open an existing file ---")
# Create a dummy file
with open("test_read.txt", "w") as f:
    f.write("This is a test file.")
open_and_read_file("test_read.txt")

print("\n--- Attempting to open a non-existent file ---")
open_and_read_file("non_existent_file.txt")

# On Unix-like systems, you might create a file with restricted permissions for testing PermissionError
# On Windows, PermissionError is less common for simple read attempts but can occur.
# Example: create a file, then change its permissions to read-only for current user
# import os
# os.chmod("test_read.txt", 0o000) # This might cause PermissionError
# print("\n--- Attempting to open a permission-denied file ---")
# open_and_read_file("test_read.txt")
# os.chmod("test_read.txt", 0o600) # Restore permissions
# Out:
# --- Attempting to open an existing file ---
# Successfully read 'test_read.txt':
# This is a test file.
#
# --- Attempting to open a non-existent file ---
# Error: The file 'non_existent_file.txt' was not found.

# %% [markdown]
# ### **9. How can you read a file line by line and store its content in a list in Python?**

# %%
# Create a dummy file
with open("lines_data.txt", "w") as f:
    f.write("Apple\n")
    f.write("Banana\n")
    f.write("Cherry\n")
    f.write("Date")

file_lines = []
try:
    with open("lines_data.txt", "r") as file:
        for line in file:
            file_lines.append(line.strip()) # .strip() removes the newline character

    print("File content stored in list:")
    print(file_lines)

except FileNotFoundError:
    print("Error: 'lines_data.txt' not found.")
except IOError as e:
    print(f"Error reading file: {e}")
# Out:
# File content stored in list:
# ['Apple', 'Banana', 'Cherry', 'Date']

# %% [markdown]
# ### **10. How can you append data to an existing file in Python?**
#
# **Answer**
#
# You open the file using the `'a'` (append) mode. If the file doesn't exist, it will be created. If it exists, new data is written at the end of the file.

# %%
file_to_append = "my_appended_data.txt"

# Create the file with some initial content if it doesn't exist
with open(file_to_append, "w") as f:
    f.write("Initial line.\n")

print(f"Initial content of '{file_to_append}':")
with open(file_to_append, "r") as f:
    print(f.read())

# Append new data
try:
    with open(file_to_append, "a") as file:
        file.write("This line is appended.\n")
        file.write("Another line added at the end.\n")
    print(f"\nSuccessfully appended data to '{file_to_append}'")

except IOError as e:
    print(f"Error appending to file: {e}")

print(f"\nContent of '{file_to_append}' after appending:")
try:
    with open(file_to_append, "r") as f:
        print(f.read())
except IOError as e:
    print(f"Error reading file after append: {e}")
# Out:
# Initial content of 'my_appended_data.txt':
# Initial line.
#
#
# Successfully appended data to 'my_appended_data.txt'
#
# Content of 'my_appended_data.txt' after appending:
# Initial line.
# This line is appended.
# Another line added at the end.

# %% [markdown]
# ### **11. Write a Python program that uses a `try-except` block to handle an error when attempting to access a dictionary key that doesn't exist?**
#
# **Answer:**
#
# You handle a `KeyError` for non-existent dictionary keys.

# %%
my_dict = {
    "name": "Alice",
    "age": 30,
    "city": "New York"
}

def get_dict_value(dictionary, key):
    try:
        value = dictionary[key]
        print(f"The value for key '{key}' is: {value}")
    except KeyError:
        print(f"Error: The key '{key}' does not exist in the dictionary.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

print("--- Accessing existing key ---")
get_dict_value(my_dict, "name")

print("\n--- Accessing non-existent key ---")
get_dict_value(my_dict, "country")

print("\n--- Accessing another existing key ---")
get_dict_value(my_dict, "age")
# Out:
# --- Accessing existing key ---
# The value for key 'name' is: Alice
#
# --- Accessing non-existent key ---
# Error: The key 'country' does not exist in the dictionary.
#
# --- Accessing another existing key ---
# The value for key 'age' is: 30

# %% [markdown]
# ### **12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions?**

# %%
def perform_operations(data, index_to_access, divisor):
    try:
        # Attempt an operation that might raise IndexError
        element = data[index_to_access]
        print(f"Accessed element at index {index_to_access}: {element}")

        # Attempt an operation that might raise ZeroDivisionError
        result = element / divisor
        print(f"Division result: {result}")

    except IndexError:
        print(f"Error: Invalid index '{index_to_access}'. Index is out of bounds for the list.")
    except ZeroDivisionError:
        print(f"Error: Cannot divide by zero. Divisor provided was {divisor}.")
    except TypeError:
        print(f"Error: A TypeError occurred. Ensure data types are correct for operations.")
    except Exception as e: # Catch any other unexpected exceptions
        print(f"An unexpected error occurred: {type(e).__name__} - {e}")
    finally:
        print("Operation attempt completed.")

print("--- Test Case 1: All operations succeed ---")
perform_operations([1, 2, 3, 4], 2, 2) # Accesses 3, then 3/2 = 1.5

print("\n--- Test Case 2: IndexError ---")
perform_operations([1, 2, 3], 5, 1) # Index 5 is out of bounds

print("\n--- Test Case 3: ZeroDivisionError ---")
perform_operations([10, 20], 0, 0) # Accesses 10, then 10/0

print("\n--- Test Case 4: TypeError (e.g., dividing string) ---")
perform_operations(["abc", "def"], 0, 2) # Accesses "abc", then "abc"/2 (TypeError)
# Out:
# --- Test Case 1: All operations succeed ---
# Accessed element at index 2: 3
# Division result: 1.5
# Operation attempt completed.
#
# --- Test Case 2: IndexError ---
# Error: Invalid index '5'. Index is out of bounds for the list.
# Operation attempt completed.
#
# --- Test Case 3: ZeroDivisionError ---
# Accessed element at index 0: 10
# Error: Cannot divide by zero. Divisor provided was 0.
# Operation attempt completed.
#
# --- Test Case 4: TypeError (e.g., dividing string) ---
# Accessed element at index 0: abc
# Error: A TypeError occurred. Ensure data types are correct for operations.
# Operation attempt completed.

# %% [markdown]
# ### **13. How would you check if a file exists before attempting to read it in Python?**
#
# **Answer:**
#
# You use the os.path.exists() function.

# %%
import os

file_to_check = "existing_file.txt"
non_existent_file = "another_non_existent.txt"

# Create a dummy existing file
with open(file_to_check, "w") as f:
    f.write("This file exists.")

if os.path.exists(file_to_check):
    print(f"'{file_to_check}' exists. Attempting to read...")
    try:
        with open(file_to_check, "r") as f:
            print(f.read())
    except IOError as e:
        print(f"Error reading '{file_to_check}': {e}")
else:
    print(f"'{file_to_check}' does not exist.")

print("-" * 30)

if os.path.exists(non_existent_file):
    print(f"'{non_existent_file}' exists. (This should not happen)")
else:
    print(f"'{non_existent_file}' does not exist. Skipping read attempt.")
# Out:
# 'existing_file.txt' exists. Attempting to read...
# This file exists.
# ------------------------------
# 'another_non_existent.txt' does not exist. Skipping read attempt.

# %% [markdown]
# ### **14. Write a program that uses the logging module to log both informational and error messages?**

# %%
import logging
logging.basicConfig(filename="app.log", level=logging.DEBUG)

logging.info("This is an info message")
logging.error("This is an error message")
# Out:
# ERROR:root:This is an error message

# %% [markdown]
# ### **15. Write a Python program that prints the content of a file and handles the case when the file is empty.**

# %%
def print_file_content_and_handle_empty(filename):
    try:
        with open(filename, "r") as file:
            content = file.read()
            if not content: # Check if the string is empty
                print(f"The file '{filename}' is empty.")
            else:
                print(f"--- Content of '{filename}' ---")
                print(content)
                print(f"--- End of '{filename}' content ---")
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
    except IOError as e:
        print(f"An I/O error occurred while reading '{filename}': {e}")

# Create a dummy non-empty file
with open("non_empty_file.txt", "w") as f:
    f.write("This file has some content.")

# Create a dummy empty file
with open("empty_file.txt", "w") as f:
    pass # Create an empty file

print_file_content_and_handle_empty("non_empty_file.txt")
print("\n" + "="*40 + "\n")
print_file_content_and_handle_empty("empty_file.txt")
print("\n" + "="*40 + "\n")
print_file_content_and_handle_empty("non_existent_file_for_test.txt")
# Out:
# --- Content of 'non_empty_file.txt' ---
# This file has some content.
# --- End of 'non_empty_file.txt' content ---
#
# ========================================
#
# The file 'empty_file.txt' is empty.
#
# ========================================
#
# Error: The file 'non_existent_file_for_test.txt' was not found.

# %% [markdown]
# ### **16. Demonstrate how to use memory profiling to check the memory usage of a small program.**
# **Answer:**
#
# For memory profiling, you'll typically use external libraries like ~memory_profiler`. First, you need to install it:

# %%
pip install memory-profiler
# Out:
# Requirement already satisfied: memory-profiler in /usr/local/lib/python3.11/dist-packages (0.61.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from memory-profiler) (5.9.5)

# %%
# Save this code as 'memory_test.py'
from memory_profiler import profile
import time

@profile
def create_large_list():
    """
    Creates a large list of integers to demonstrate memory usage.
    """
    print("Creating a list of 10 million integers...")
    my_list = list(range(10_000_000))
    print(f"List size: {len(my_list)} elements.")
    # Keep the list in scope for memory_profiler to track
    # Otherwise, it might be garbage collected too quickly
    time.sleep(1) # Keep it alive briefly for profiling
    del my_list # Explicitly delete to show memory release

@profile
def create_large_string():
    """
    Creates a large string to demonstrate memory usage.
    """
    print("Creating a large string (10MB)...")
    long_string = "A" * (10 * 1024 * 1024) # 10 MB string
    print(f"String length: {len(long_string)} characters.")
    time.sleep(1)
    del long_string

if __name__ == "__main__":
    print("--- Memory Usage Test ---")
    create_large_list()
    print("\n")
    create_large_string()
    print("\n--- Memory Usage Test Complete ---")
# Out:
# --- Memory Usage Test ---
# ERROR: Could not find file /tmp/ipython-input-4142508221.py
# Creating a list of 10 million integers...
# List size: 10000000 elements.
#
#
# ERROR: Could not find file /tmp/ipython-input-4142508221.py
# Creating a large string (10MB)...
# String length: 10485760 characters.
#
# --- Memory Usage Test Complete ---

# %% [markdown]
# ### **17. Write a Python program to create and write a list of numbers to a file, one number per line.**

# %%
numbers = [10, 20, 30, 45, 55, 60, 75, 80, 95, 100]
output_file = "numbers_list.txt"

try:
    with open(output_file, "w") as file:
        for number in numbers:
            file.write(str(number) + "\n") # Convert number to string and add newline
    print(f"Successfully wrote numbers to '{output_file}'")

    # Verify content
    print(f"\nContent of '{output_file}':")
    with open(output_file, "r") as file:
        print(file.read())

except IOError as e:
    print(f"Error writing to file: {e}")
# Out:
# Successfully wrote numbers to 'numbers_list.txt'
#
# Content of 'numbers_list.txt':
# 10
# 20
# 30
# 45
# 55
# 60
# 75
# 80
# 95
# 100

# %% [markdown]
# ### **18. How would you implement a basic logging setup that logs to a file with rotation after 1MB.**

# %%
import logging
from logging.handlers import RotatingFileHandler

# Create logger
logger = logging.getLogger("my_logger")
logger.setLevel(logging.INFO)

# Create a rotating file handler
handler = RotatingFileHandler(
    "app.log",       # log file name
    maxBytes=1*1024*1024,  # 1MB
    backupCount=5    # keep last 5 log files
)

# Create formatter and add it to the handler
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Add the handler to the logger
logger.addHandler(handler)

# Example log messages
for i in range(10000):
    logger.info(f"Log message {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:my_logger:Log message 5000
# INFO:my_logger:Log message 5001
# INFO:my_logger:Log message 5002
# INFO:my_logger:Log message 5003
# INFO:my_logger:Log message 5004
# INFO:my_logger:Log message 5005
# INFO:my_logger:Log message 5006
# INFO:my_logger:Log message 5007
# INFO:my_logger:Log message 5008
# INFO:my_logger:Log message 5009
# INFO:my_logger:Log message 5010
# INFO:my_logger:Log message 5011
# INFO:my_logger:Log message 5012
# INFO:my_logger:Log message 5013
# INFO:my_logger:Log message 5014
# INFO:my_logger:Log message 5015
# INFO:my_logger:Log message 5016
# INFO:my_logger:Log message 5017
# INFO:my_logger:Log message 5018
# INFO:my_logger:Log message 5019
# INFO:my_logger:Log message 5020
# INFO:my_logger:Log message 5021
# INFO:my_logger:Log message 5022
# INFO:my_logger:Log message 5023
# INFO:my_logger:Log message 5024
# INFO:my_logger:Log message 5025
# INFO:my_logger:Log message 5026
# INFO:my_logger:Log message 5027
# INFO:my_logger:Log message 5028
# INFO:my_logger:Log message 5029
# INFO:my_logger:Log message 5030
# INFO:my_logger:Log message 5031
# INFO:my_logger:Log message 5032
# INFO:my_logger:Log message 5033
# INFO:my_logger:Log message 5034
# INFO:my_logger:Log message 5035
# INFO:my_logger:Log message 5036
# INFO:my_logger:Log message 5037
# INFO:my_logger:Log message 5038
# INFO:my_logger:Log message 5039
# INFO:my_logger:Log message 5040
# INFO:my_logger:Log message 5041
# INFO:my_logger:Log message 5042
# INFO:my_logger:Log message 5043
# INFO:my_logger:Log message 5044
# INFO:my_logger:Log message 5045
# INFO:my_logger:Log message 5046
# INFO:my_logger:Log message 5047
# INFO:my_logger:Log message 5048
# INFO:my_logger:Log message 5049
# INFO:my_logger:Log message 5050
# INFO:my_logger:Log message 5051
# INFO:my_logger:Log message 5052
# INFO:my_logger:Log message 5053
# INFO:my_logger:Log message 5054
# INFO:my_logger:Log message 5055
# INFO:my_logger:Log message 5056
# INFO:my_logger:Log message 5057
# INFO:my_logger:Log message 5058
# INFO:my_logger:Log message 5059
# INFO:my_logger:Log message 5060
# INFO:my_logger:Log message 5061
# INFO:my_logger:Log message 5062
# INFO:my_logger:Log message 5063
# INFO:my_logger:Log message 5064
# INFO:my_logger:Log message 5065
# INFO:my_logger:Log message 5066
# INFO:my_logger:Log message 5067
# INFO:my_logger:Log message 5068
# INFO:my_logger:Log message 5069
# INFO:my_logger:Log message 5070
# INFO:my_logger:Log message 5071
# INFO:my_logger:Log message 5072
# INFO:my_logger:Log message 5073
# INFO:my_logger:Log message 5074
# INFO:my_logger:Log message 5075
# INFO:my_logger:Log message 5076
# INFO:my_logger:Log message 5077
# INFO:my_logger:Log message 5078
# INFO:my_logger:Log message 5079
# INFO:my_logger:Log message 5080
# INFO:my_logger:Log message 5081
# INFO:my_logger:Log message 5082
# INFO:my_logger:Log message 5083
# INFO:my_logger:Log message 5084
# INFO:my_logger:Log message 5085
# INFO:my_logger:Log message 5086
# INFO:my_logger:Log message 5087
# INFO:my_logger:Log message 5088
# INFO:my_logger:Log message 5089
# INFO:my_logger:Log message 5090
# INFO:my_logger:Log message 5091
# INFO:my_logger:Log message 5092
# INFO:my_logger:Log message 5093
# INFO:my_logger:Log message 5094
# INFO:my_logger:Log message 5095
# INFO:my_logger:Log message 5096
# INFO:my_logger:Log message 5097
# INFO:my_logger:Log message 5098
# INFO:my_logger:Log message 5099
# INFO:my_logger:Log message 5100
# INFO:my_logger:Log message 5101
# INFO:my_logger:Log message 5102
# INFO:my_logger:Log message 5103
# INFO:my_logger:Log message 5104
# INFO:my_logger:Log message 5105
# INFO:my_logger:Log message 5106
# INFO:my_logger:Log message 5107
# INFO:my_logger:Log message 5108
# INFO:my_logger:Log message 5109
# INFO:my_logger:Log message 5110
# INFO:my_logger:Log message 5111
# INFO:my_logger:Log message 5112
# INFO:my_logger:Log message 5113
# INFO:my_logger:Log message 5114
# INFO:my_logger:Log message 5115
# INFO:my_logger:Log message 5116
# INFO:my_logger:Log message 5117
# INFO:my_logger:Log message 5118
# INFO:my_logger:Log message 5119
# INFO:my_logger:Log message 5120
# INFO:my_logger:Log message 5121
# INFO:my_logger:Log message 5122
# INFO:my_logger:Log message 5123
# INFO:my_logger:Log message 5124
# INFO:my_logger:Log message 5125
# INFO:my_logger:Log message 5126
# INFO:my_logger:Log message 5127
# INFO:my_logger:Log message 5128
# INFO:my_logger:Log message 5129
# INFO:my_logger:Log message 5130
# INFO:my_logger:Log message 5131
# INFO:my_logger:Log message 5132
# INFO:my_logger:Log message 5133
# INFO:my_logger:Log message 5134
# INFO:my_logger:Log message 5135
# INFO:my_logger:Log message 5136
# INFO:my_logger:Log message 5137
# INFO:my_logger:Log message 5138
# INFO:my_logger:Log message 5139
# INFO:my_logger:Log message 5140
# INFO:my_logger:Log message 5141
# INFO:my_logger:Log message 5142
# INFO:my_logger:Log message 5143
# INFO:my_logger:Log message 5144
# INFO:my_logger:Log message 5145
# INFO:my_logger:Log message 5146
# INFO:my_logger:Log message 5147
# INFO:my_logger:Log message 5148
# INFO:my_logger:Log message 5149
# INFO:my_logger:Log message 5150
# INFO:my_logger:Log message 5151
# INFO:my_logger:Log message 5152
# INFO:my_logger:Log message 5153
# INFO:my_logger:Log message 5154
# INFO:my_logger:Log message 5155
# INFO:my_logger:Log message 5156
# INFO:my_logger:Log message 5157
# INFO:my_logger:Log message 5158
# INFO:my_logger:Log message 5159
# INFO:my_logger:Log message 5160
# INFO:my_logger:Log message 5161
# INFO:my_logger:Log message 5162
# INFO:my_logger:Log message 5163
# INFO:my_logger:Log message 5164
# INFO:my_logger:Log message 5165
# INFO:my_logger:Log message 5166
# INFO:my_logger:Log message 5167
# INFO:my_logger:Log message 5168
# INFO:my_logger:Log message 5169
# INFO:my_logger:Log message 5170
# INFO:my_logger:Log message 5171
# INFO:my_logger:Log message 5172
# INFO:my_logger:Log message 5173
# INFO:my_logger:Log message 5174
# INFO:my_logger:Log message 5175
# INFO:my_logger:Log message 5176
# INFO:my_logger:Log message 5177
# INFO:my_logger:Log message 5178
# INFO:my_logger:Log message 5179
# INFO:my_logger:Log message 5180
# INFO:my_logger:Log message 5181
# INFO:my_logger:Log message 5182
# INFO:my_logger:Log message 5183
# INFO:my_logger:Log message 5184
# INFO:my_logger:Log message 5185
# INFO:my_logger:Log message 5186
# INFO:my_logger:Log message 5187
# INFO:my_logger:Log message 5188
# INFO:my_logger:Log message 5189
# INFO:my_logger:Log message 5190
# INFO:my_logger:Log message 5191
# INFO:my_logger:Log message 5192
# INFO:my_logger:Log message 5193
# INFO:my_logger:Log message 5194
# INFO:my_logger:Log message 5195
# INFO:my_logger:Log message 5196
# INFO:my_logger:Log message 5197
# INFO:my_logger:Log message 5198
# INFO:my_logger:Log message 5199
# INFO:my_logger:Log message 5200
# INFO:my_logger:Log message 5201
# INFO:my_logger:Log message 5202
# INFO:my_logger:Log message 5203
# INFO:my_logger:Log message 5204
# INFO:my_logger:Log message 5205
# INFO:my_logger:Log message 5206
# INFO:my_logger:Log message 5207
# INFO:my_logger:Log message 5208
# INFO:my_logger:Log message 5209
# INFO:my_logger:Log message 5210
# INFO:my_logger:Log message 5211
# INFO:my_logger:Log message 5212
# INFO:my_logger:Log message 5213
# INFO:my_logger:Log message 5214
# INFO:my_logger:Log message 5215
# INFO:my_logger:Log message 5216
# INFO:my_logger:Log message 5217
# INFO:my_logger:Log message 5218
# INFO:my_logger:Log message 5219
# INFO:my_logger:Log message 5220
# INFO:my_logger:Log message 5221
# INFO:my_logger:Log message 5222
# INFO:my_logger:Log message 5223
# INFO:my_logger:Log message 5224
# INFO:my_logger:Log message 5225
# INFO:my_logger:Log message 5226
# INFO:my_logger:Log message 5227
# INFO:my_logger:Log message 5228
# INFO:my_logger:Log message 5229
# INFO:my_logger:Log message 5230
# INFO:my_logger:Log message 5231
# INFO:my_logger:Log message 5232
# INFO:my_logger:Log message 5233
# INFO:my_logger:Log message 5234
# INFO:my_logger:Log message 5235
# INFO:my_logger:Log message 5236
# INFO:my_logger:Log message 5237
# INFO:my_logger:Log message 5238
# INFO:my_logger:Log message 5239
# INFO:my_logger:Log message 5240
# INFO:my_logger:Log message 5241
# INFO:my_logger:Log message 5242
# INFO:my_logger:Log message 5243
# INFO:my_logger:Log message 5244
# INFO:my_logger:Log message 5245
# INFO:my_logger:Log message 5246
# INFO:my_logger:Log message 5247
# INFO:my_logger:Log message 5248
# INFO:my_logger:Log message 5249
# INFO:my_logger:Log message 5250
# INFO:my_logger:Log message 5251
# INFO:my_logger:Log message 5252
# INFO:my_logger:Log message 5253
# INFO:my_logger:Log message 5254
# INFO:my_logger:Log message 5255
# INFO:my_logger:Log message 5256
# INFO:my_logger:Log message 5257
# INFO:my_logger:Log message 5258
# INFO:my_logger:Log message 5259
# INFO:my_logger:Log message 5260
# INFO:my_logger:Log message 5261
# INFO:my_logger:Log message 5262
# INFO:my_logger:Log message 5263
# INFO:my_logger:Log message 5264
# INFO:my_logger:Log message 5265
# INFO:my_logger:Log message 5266
# INFO:my_logger:Log message 5267
# INFO:my_logger:Log message 5268
# INFO:my_logger:Log message 5269
# INFO:my_logger:Log message 5270
# INFO:my_logger:Log message 5271
# INFO:my_logger:Log message 5272
# INFO:my_logger:Log message 5273
# INFO:my_logger:Log message 5274
# INFO:my_logger:Log message 5275
# INFO:my_logger:Log message 5276
# INFO:my_logger:Log message 5277
# INFO:my_logger:Log message 5278
# INFO:my_logger:Log message 5279
# INFO:my_logger:Log message 5280
# INFO:my_logger:Log message 5281
# INFO:my_logger:Log message 5282
# INFO:my_logger:Log message 5283
# INFO:my_logger:Log message 5284
# INFO:my_logger:Log message 5285
# INFO:my_logger:Log message 5286
# INFO:my_logger:Log message 5287
# INFO:my_logger:Log message 5288
# INFO:my_logger:Log message 5289
# INFO:my_logger:Log message 5290
# INFO:my_logger:Log message 5291
# INFO:my_logger:Log message 5292
# INFO:my_logger:Log message 5293
# INFO:my_logger:Log message 5294
# INFO:my_logger:Log message 5295
# INFO:my_logger:Log message 5296
# INFO:my_logger:Log message 5297
# INFO:my_logger:Log message 5298
# INFO:my_logger:Log message 5299
# INFO:my_logger:Log message 5300
# INFO:my_logger:Log message 5301
# INFO:my_logger:Log message 5302
# INFO:my_logger:Log message 5303
# INFO:my_logger:Log message 5304
# INFO:my_logger:Log message 5305
# INFO:my_logger:Log message 5306
# INFO:my_logger:Log message 5307
# INFO:my_logger:Log message 5308
# INFO:my_logger:Log message 5309
# INFO:my_logger:Log message 5310
# INFO:my_logger:Log message 5311
# INFO:my_logger:Log message 5312
# INFO:my_logger:Log message 5313
# INFO:my_logger:Log message 5314
# INFO:my_logger:Log message 5315
# INFO:my_logger:Log message 5316
# INFO:my_logger:Log message 5317
# INFO:my_logger:Log message 5318
# INFO:my_logger:Log message 5319
# INFO:my_logger:Log message 5320
# INFO:my_logger:Log message 5321
# INFO:my_logger:Log message 5322
# INFO:my_logger:Log message 5323
# INFO:my_logger:Log message 5324
# INFO:my_logger:Log message 5325
# INFO:my_logger:Log message 5326
# INFO:my_logger:Log message 5327
# INFO:my_logger:Log message 5328
# INFO:my_logger:Log message 5329
# INFO:my_logger:Log message 5330
# INFO:my_logger:Log message 5331
# INFO:my_logger:Log message 5332
# INFO:my_logger:Log message 5333
# INFO:my_logger:Log message 5334
# INFO:my_logger:Log message 5335
# INFO:my_logger:Log message 5336
# INFO:my_logger:Log message 5337
# INFO:my_logger:Log message 5338
# INFO:my_logger:Log message 5339
# INFO:my_logger:Log message 5340
# INFO:my_logger:Log message 5341
# INFO:my_logger:Log message 5342
# INFO:my_logger:Log message 5343
# INFO:my_logger:Log message 5344
# INFO:my_logger:Log message 5345
# INFO:my_logger:Log message 5346
# INFO:my_logger:Log message 5347
# INFO:my_logger:Log message 5348
# INFO:my_logger:Log message 5349
# INFO:my_logger:Log message 5350
# INFO:my_logger:Log message 5351
# INFO:my_logger:Log message 5352
# INFO:my_logger:Log message 5353
# INFO:my_logger:Log message 5354
# INFO:my_logger:Log message 5355
# INFO:my_logger:Log message 5356
# INFO:my_logger:Log message 5357
# INFO:my_logger:Log message 5358
# INFO:my_logger:Log message 5359
# INFO:my_logger:Log message 5360
# INFO:my_logger:Log message 5361
# INFO:my_logger:Log message 5362
# INFO:my_logger:Log message 5363
# INFO:my_logger:Log message 5364
# INFO:my_logger:Log message 5365
# INFO:my_logger:Log message 5366
# INFO:my_logger:Log message 5367
# INFO:my_logger:Log message 5368
# INFO:my_logger:Log message 5369
# INFO:my_logger:Log message 5370
# INFO:my_logger:Log message 5371
# INFO:my_logger:Log message 5372
# INFO:my_logger:Log message 5373
# INFO:my_logger:Log message 5374
# INFO:my_logger:Log message 5375
# INFO:my_logger:Log message 5376
# INFO:my_logger:Log message 5377
# INFO:my_logger:Log message 5378
# INFO:my_logger:Log message 5379
# INFO:my_logger:Log message 5380
# INFO:my_logger:Log message 5381
# INFO:my_logger:Log message 5382
# INFO:my_logger:Log message 5383
# INFO:my_logger:Log message 5384
# INFO:my_logger:Log message 5385
# INFO:my_logger:Log message 5386
# INFO:my_logger:Log message 5387
# INFO:my_logger:Log message 5388
# INFO:my_logger:Log message 5389
# INFO:my_logger:Log message 5390
# INFO:my_logger:Log message 5391
# INFO:my_logger:Log message 5392
# INFO:my_logger:Log message 5393
# INFO:my_logger:Log message 5394
# INFO:my_logger:Log message 5395
# INFO:my_logger:Log message 5396
# INFO:my_logger:Log message 5397
# INFO:my_logger:Log message 5398
# INFO:my_logger:Log message 5399
# INFO:my_logger:Log message 5400
# INFO:my_logger:Log message 5401
# INFO:my_logger:Log message 5402
# INFO:my_logger:Log message 5403
# INFO:my_logger:Log message 5404
# INFO:my_logger:Log message 5405
# INFO:my_logger:Log message 5406
# INFO:my_logger:Log message 5407
# INFO:my_logger:Log message 5408
# INFO:my_logger:Log message 5409
# INFO:my_logger:Log message 5410
# INFO:my_logger:Log message 5411
# INFO:my_logger:Log message 5412
# INFO:my_logger:Log message 5413
# INFO:my_logger:Log message 5414
# INFO:my_logger:Log message 5415
# INFO:my_logger:Log message 5416
# INFO:my_logger:Log message 5417
# INFO:my_logger:Log message 5418
# INFO:my_logger:Log message 5419
# INFO:my_logger:Log message 5420
# INFO:my_logger:Log message 5421
# INFO:my_logger:Log message 5422
# INFO:my_logger:Log message 5423
# INFO:my_logger:Log message 5424
# INFO:my_logger:Log message 5425
# INFO:my_logger:Log message 5426
# INFO:my_logger:Log message 5427
# INFO:my_logger:Log message 5428
# INFO:my_logger:Log message 5429
# INFO:my_logger:Log message 5430
# INFO:my_logger:Log message 5431
# INFO:my_logger:Log message 5432
# INFO:my_logger:Log message 5433
# INFO:my_logger:Log message 5434
# INFO:my_logger:Log message 5435
# INFO:my_logger:Log message 5436
# INFO:my_logger:Log message 5437
# INFO:my_logger:Log message 5438
# INFO:my_logger:Log message 5439
# INFO:my_logger:Log message 5440
# INFO:my_logger:Log message 5441
# INFO:my_logger:Log message 5442
# INFO:my_logger:Log message 5443
# INFO:my_logger:Log message 5444
# INFO:my_logger:Log message 5445
# INFO:my_logger:Log message 5446
# INFO:my_logger:Log message 5447
# INFO:my_logger:Log message 5448
# INFO:my_logger:Log message 5449
# INFO:my_logger:Log message 5450
# INFO:my_logger:Log message 5451
# INFO:my_logger:Log message 5452
# INFO:my_logger:Log message 5453
# INFO:my_logger:Log message 5454
# INFO:my_logger:Log message 5455
# INFO:my_logger:Log message 5456
# INFO:my_logger:Log message 5457
# INFO:my_logger:Log message 5458
# INFO:my_logger:Log message 5459
# INFO:my_logger:Log message 5460
# INFO:my_logger:Log message 5461
# INFO:my_logger:Log message 5462
# INFO:my_logger:Log message 5463
# INFO:my_logger:Log message 5464
# INFO:my_logger:Log message 5465
# INFO:my_logger:Log message 5466
# INFO:my_logger:Log message 5467
# INFO:my_logger:Log message 5468
# INFO:my_logger:Log message 5469
# INFO:my_logger:Log message 5470
# INFO:my_logger:Log message 5471
# INFO:my_logger:Log message 5472
# INFO:my_logger:Log message 5473
# INFO:my_logger:Log message 5474
# INFO:my_logger:Log message 5475
# INFO:my_logger:Log message 5476
# INFO:my_logger:Log message 5477
# INFO:my_logger:Log message 5478
# INFO:my_logger:Log message 5479
# INFO:my_logger:Log message 5480
# INFO:my_logger:Log message 5481
# INFO:my_logger:Log message 5482
# INFO:my_logger:Log message 5483
# INFO:my_logger:Log message 5484
# INFO:my_logger:Log message 5485
# INFO:my_logger:Log message 5486
# INFO:my_logger:Log message 5487
# INFO:my_logger:Log message 5488
# INFO:my_logger:Log message 5489
# INFO:my_logger:Log message 5490
# INFO:my_logger:Log message 5491
# INFO:my_logger:Log message 5492
# INFO:my_logger:Log message 5493
# INFO:my_logger:Log message 5494
# INFO:my_logger:Log message 5495
# INFO:my_logger:Log message 5496
# INFO:my_logger:Log message 5497
# INFO:my_logger:Log message 5498
# INFO:my_logger:Log message 5499
# INFO:my_logger:Log message 5500
# INFO:my_logger:Log message 5501
# INFO:my_logger:Log message 5502
# INFO:my_logger:Log message 5503
# INFO:my_logger:Log message 5504
# INFO:my_logger:Log message 5505
# INFO:my_logger:Log message 5506
# INFO:my_logger:Log message 5507
# INFO:my_logger:Log message 5508
# INFO:my_logger:Log message 5509
# INFO:my_logger:Log message 5510
# INFO:my_logger:Log message 5511
# INFO:my_logger:Log message 5512
# INFO:my_logger:Log message 5513
# INFO:my_logger:Log message 5514
# INFO:my_logger:Log message 5515
# INFO:my_logger:Log message 5516
# INFO:my_logger:Log message 5517
# INFO:my_logger:Log message 5518
# INFO:my_logger:Log message 5519
# INFO:my_logger:Log message 5520
# INFO:my_logger:Log message 5521
# INFO:my_logger:Log message 5522
# INFO:my_logger:Log message 5523
# INFO:my_logger:Log message 5524
# INFO:my_logger:Log message 5525
# INFO:my_logger:Log message 5526
# INFO:my_logger:Log message 5527
# INFO:my_logger:Log message 5528
# INFO:my_logger:Log message 5529
# INFO:my_logger:Log message 5530
# INFO:my_logger:Log message 5531
# INFO:my_logger:Log message 5532
# INFO:my_logger:Log message 5533
# INFO:my_logger:Log message 5534
# INFO:my_logger:Log message 5535
# INFO:my_logger:Log message 5536
# INFO:my_logger:Log message 5537
# INFO:my_logger:Log message 5538
# INFO:my_logger:Log message 5539
# INFO:my_logger:Log message 5540
# INFO:my_logger:Log message 5541
# INFO:my_logger:Log message 5542
# INFO:my_logger:Log message 5543
# INFO:my_logger:Log message 5544
# INFO:my_logger:Log message 5545
# INFO:my_logger:Log message 5546
# INFO:my_logger:Log message 5547
# INFO:my_logger:Log message 5548
# INFO:my_logger:Log message 5549
# INFO:my_logger:Log message 5550
# INFO:my_logger:Log message 5551
# INFO:my_logger:Log message 5552
# INFO:my_logger:Log message 5553
# INFO:my_logger:Log message 5554
# INFO:my_logger:Log message 5555
# INFO:my_logger:Log message 5556
# INFO:my_logger:Log message 5557
# INFO:my_logger:Log message 5558
# INFO:my_logger:Log message 5559
# INFO:my_logger:Log message 5560
# INFO:my_logger:Log message 5561
# INFO:my_logger:Log message 5562
# INFO:my_logger:Log message 5563
# INFO:my_logger:Log message 5564
# INFO:my_logger:Log message 5565
# INFO:my_logger:Log message 5566
# INFO:my_logger:Log message 5567
# INFO:my_logger:Log message 5568
# INFO:my_logger:Log message 5569
# INFO:my_logger:Log message 5570
# INFO:my_logger:Log message 5571
# INFO:my_logger:Log message 5572
# INFO:my_logger:Log message 5573
# INFO:my_logger:Log message 5574
# INFO:my_logger:Log message 5575
# INFO:my_logger:Log message 5576
# INFO:my_logger:Log message 5577
# INFO:my_logger:Log message 5578
# INFO:my_logger:Log message 5579
# INFO:my_logger:Log message 5580
# INFO:my_logger:Log message 5581
# INFO:my_logger:Log message 5582
# INFO:my_logger:Log message 5583
# INFO:my_logger:Log message 5584
# INFO:my_logger:Log message 5585
# INFO:my_logger:Log message 5586
# INFO:my_logger:Log message 5587
# INFO:my_logger:Log message 5588
# INFO:my_logger:Log message 5589
# INFO:my_logger:Log message 5590
# INFO:my_logger:Log message 5591
# INFO:my_logger:Log message 5592
# INFO:my_logger:Log message 5593
# INFO:my_logger:Log message 5594
# INFO:my_logger:Log message 5595
# INFO:my_logger:Log message 5596
# INFO:my_logger:Log message 5597
# INFO:my_logger:Log message 5598
# INFO:my_logger:Log message 5599
# INFO:my_logger:Log message 5600
# INFO:my_logger:Log message 5601
# INFO:my_logger:Log message 5602
# INFO:my_logger:Log message 5603
# INFO:my_logger:Log message 5604
# INFO:my_logger:Log message 5605
# INFO:my_logger:Log message 5606
# INFO:my_logger:Log message 5607
# INFO:my_logger:Log message 5608
# INFO:my_logger:Log message 5609
# INFO:my_logger:Log message 5610
# INFO:my_logger:Log message 5611
# INFO:my_logger:Log message 5612
# INFO:my_logger:Log message 5613
# INFO:my_logger:Log message 5614
# INFO:my_logger:Log message 5615
# INFO:my_logger:Log message 5616
# INFO:my_logger:Log message 5617
# INFO:my_logger:Log message 5618
# INFO:my_logger:Log message 5619
# INFO:my_logger:Log message 5620
# INFO:my_logger:Log message 5621
# INFO:my_logger:Log message 5622
# INFO:my_logger:Log message 5623
# INFO:my_logger:Log message 5624
# INFO:my_logger:Log message 5625
# INFO:my_logger:Log message 5626
# INFO:my_logger:Log message 5627
# INFO:my_logger:Log message 5628
# INFO:my_logger:Log message 5629
# INFO:my_logger:Log message 5630
# INFO:my_logger:Log message 5631
# INFO:my_logger:Log message 5632
# INFO:my_logger:Log message 5633
# INFO:my_logger:Log message 5634
# INFO:my_logger:Log message 5635
# INFO:my_logger:Log message 5636
# INFO:my_logger:Log message 5637
# INFO:my_logger:Log message 5638
# INFO:my_logger:Log message 5639
# INFO:my_logger:Log message 5640
# INFO:my_logger:Log message 5641
# INFO:my_logger:Log message 5642
# INFO:my_logger:Log message 5643
# INFO:my_logger:Log message 5644
# INFO:my_logger:Log message 5645
# INFO:my_logger:Log message 5646
# INFO:my_logger:Log message 5647
# INFO:my_logger:Log message 5648
# INFO:my_logger:Log message 5649
# INFO:my_logger:Log message 5650
# INFO:my_logger:Log message 5651
# INFO:my_logger:Log message 5652
# INFO:my_logger:Log message 5653
# INFO:my_logger:Log message 5654
# INFO:my_logger:Log message 5655
# INFO:my_logger:Log message 5656
# INFO:my_logger:Log message 5657
# INFO:my_logger:Log message 5658
# INFO:my_logger:Log message 5659
# INFO:my_logger:Log message 5660
# INFO:my_logger:Log message 5661
# INFO:my_logger:Log message 5662
# INFO:my_logger:Log message 5663
# INFO:my_logger:Log message 5664
# INFO:my_logger:Log message 5665
# INFO:my_logger:Log message 5666
# INFO:my_logger:Log message 5667
# INFO:my_logger:Log message 5668
# INFO:my_logger:Log message 5669
# INFO:my_logger:Log message 5670
# INFO:my_logger:Log message 5671
# INFO:my_logger:Log message 5672
# INFO:my_logger:Log message 5673
# INFO:my_logger:Log message 5674
# INFO:my_logger:Log message 5675
# INFO:my_logger:Log message 5676
# INFO:my_logger:Log message 5677
# INFO:my_logger:Log message 5678
# INFO:my_logger:Log message 5679
# INFO:my_logger:Log message 5680
# INFO:my_logger:Log message 5681
# INFO:my_logger:Log message 5682
# INFO:my_logger:Log message 5683
# INFO:my_logger:Log message 5684
# INFO:my_logger:Log message 5685
# INFO:my_logger:Log message 5686
# INFO:my_logger:Log message 5687
# INFO:my_logger:Log message 5688
# INFO:my_logger:Log message 5689
# INFO:my_logger:Log message 5690
# INFO:my_logger:Log message 5691
# INFO:my_logger:Log message 5692
# INFO:my_logger:Log message 5693
# INFO:my_logger:Log message 5694
# INFO:my_logger:Log message 5695
# INFO:my_logger:Log message 5696
# INFO:my_logger:Log message 5697
# INFO:my_logger:Log message 5698
# INFO:my_logger:Log message 5699
# INFO:my_logger:Log message 5700
# INFO:my_logger:Log message 5701
# INFO:my_logger:Log message 5702
# INFO:my_logger:Log message 5703
# INFO:my_logger:Log message 5704
# INFO:my_logger:Log message 5705
# INFO:my_logger:Log message 5706
# INFO:my_logger:Log message 5707
# INFO:my_logger:Log message 5708
# INFO:my_logger:Log message 5709
# INFO:my_logger:Log message 5710
# INFO:my_logger:Log message 5711
# INFO:my_logger:Log message 5712
# INFO:my_logger:Log message 5713
# INFO:my_logger:Log message 5714
# INFO:my_logger:Log message 5715
# INFO:my_logger:Log message 5716
# INFO:my_logger:Log message 5717
# INFO:my_logger:Log message 5718
# INFO:my_logger:Log message 5719
# INFO:my_logger:Log message 5720
# INFO:my_logger:Log message 5721
# INFO:my_logger:Log message 5722
# INFO:my_logger:Log message 5723
# INFO:my_logger:Log message 5724
# INFO:my_logger:Log message 5725
# INFO:my_logger:Log message 5726
# INFO:my_logger:Log message 5727
# INFO:my_logger:Log message 5728
# INFO:my_logger:Log message 5729
# INFO:my_logger:Log message 5730
# INFO:my_logger:Log message 5731
# INFO:my_logger:Log message 5732
# INFO:my_logger:Log message 5733
# INFO:my_logger:Log message 5734
# INFO:my_logger:Log message 5735
# INFO:my_logger:Log message 5736
# INFO:my_logger:Log message 5737
# INFO:my_logger:Log message 5738
# INFO:my_logger:Log message 5739
# INFO:my_logger:Log message 5740
# INFO:my_logger:Log message 5741
# INFO:my_logger:Log message 5742
# INFO:my_logger:Log message 5743
# INFO:my_logger:Log message 5744
# INFO:my_logger:Log message 5745
# INFO:my_logger:Log message 5746
# INFO:my_logger:Log message 5747
# INFO:my_logger:Log message 5748
# INFO:my_logger:Log message 5749
# INFO:my_logger:Log message 5750
# INFO:my_logger:Log message 5751
# INFO:my_logger:Log message 5752
# INFO:my_logger:Log message 5753
# INFO:my_logger:Log message 5754
# INFO:my_logger:Log message 5755
# INFO:my_logger:Log message 5756
# INFO:my_logger:Log message 5757
# INFO:my_logger:Log message 5758
# INFO:my_logger:Log message 5759
# INFO:my_logger:Log message 5760
# INFO:my_logger:Log message 5761
# INFO:my_logger:Log message 5762
# INFO:my_logger:Log message 5763
# INFO:my_logger:Log message 5764
# INFO:my_logger:Log message 5765
# INFO:my_logger:Log message 5766
# INFO:my_logger:Log message 5767
# INFO:my_logger:Log message 5768
# INFO:my_logger:Log message 5769
# INFO:my_logger:Log message 5770
# INFO:my_logger:Log message 5771
# INFO:my_logger:Log message 5772
# INFO:my_logger:Log message 5773
# INFO:my_logger:Log message 5774
# INFO:my_logger:Log message 5775
# INFO:my_logger:Log message 5776
# INFO:my_logger:Log message 5777
# INFO:my_logger:Log message 5778
# INFO:my_logger:Log message 5779
# INFO:my_logger:Log message 5780
# INFO:my_logger:Log message 5781
# INFO:my_logger:Log message 5782
# INFO:my_logger:Log message 5783
# INFO:my_logger:Log message 5784
# INFO:my_logger:Log message 5785
# INFO:my_logger:Log message 5786
# INFO:my_logger:Log message 5787
# INFO:my_logger:Log message 5788
# INFO:my_logger:Log message 5789
# INFO:my_logger:Log message 5790
# INFO:my_logger:Log message 5791
# INFO:my_logger:Log message 5792
# INFO:my_logger:Log message 5793
# INFO:my_logger:Log message 5794
# INFO:my_logger:Log message 5795
# INFO:my_logger:Log message 5796
# INFO:my_logger:Log message 5797
# INFO:my_logger:Log message 5798
# INFO:my_logger:Log message 5799
# INFO:my_logger:Log message 5800
# INFO:my_logger:Log message 5801
# INFO:my_logger:Log message 5802
# INFO:my_logger:Log message 5803
# INFO:my_logger:Log message 5804
# INFO:my_logger:Log message 5805
# INFO:my_logger:Log message 5806
# INFO:my_logger:Log message 5807
# INFO:my_logger:Log message 5808
# INFO:my_logger:Log message 5809
# INFO:my_logger:Log message 5810
# INFO:my_logger:Log message 5811
# INFO:my_logger:Log message 5812
# INFO:my_logger:Log message 5813
# INFO:my_logger:Log message 5814
# INFO:my_logger:Log message 5815
# INFO:my_logger:Log message 5816
# INFO:my_logger:Log message 5817
# INFO:my_logger:Log message 5818
# INFO:my_logger:Log message 5819
# INFO:my_logger:Log message 5820
# INFO:my_logger:Log message 5821
# INFO:my_logger:Log message 5822
# INFO:my_logger:Log message 5823
# INFO:my_logger:Log message 5824
# INFO:my_logger:Log message 5825
# INFO:my_logger:Log message 5826
# INFO:my_logger:Log message 5827
# INFO:my_logger:Log message 5828
# INFO:my_logger:Log message 5829
# INFO:my_logger:Log message 5830
# INFO:my_logger:Log message 5831
# INFO:my_logger:Log message 5832
# INFO:my_logger:Log message 5833
# INFO:my_logger:Log message 5834
# INFO:my_logger:Log message 5835
# INFO:my_logger:Log message 5836
# INFO:my_logger:Log message 5837
# INFO:my_logger:Log message 5838
# INFO:my_logger:Log message 5839
# INFO:my_logger:Log message 5840
# INFO:my_logger:Log message 5841
# INFO:my_logger:Log message 5842
# INFO:my_logger:Log message 5843
# INFO:my_logger:Log message 5844
# INFO:my_logger:Log message 5845
# INFO:my_logger:Log message 5846
# INFO:my_logger:Log message 5847
# INFO:my_logger:Log message 5848
# INFO:my_logger:Log message 5849
# INFO:my_logger:Log message 5850
# INFO:my_logger:Log message 5851
# INFO:my_logger:Log message 5852
# INFO:my_logger:Log message 5853
# INFO:my_logger:Log message 5854
# INFO:my_logger:Log message 5855
# INFO:my_logger:Log message 5856
# INFO:my_logger:Log message 5857
# INFO:my_logger:Log message 5858
# INFO:my_logger:Log message 5859
# INFO:my_logger:Log message 5860
# INFO:my_logger:Log message 5861
# INFO:my_logger:Log message 5862
# INFO:my_logger:Log message 5863
# INFO:my_logger:Log message 5864
# INFO:my_logger:Log message 5865
# INFO:my_logger:Log message 5866
# INFO:my_logger:Log message 5867
# INFO:my_logger:Log message 5868
# INFO:my_logger:Log message 5869
# INFO:my_logger:Log message 5870
# INFO:my_logger:Log message 5871
# INFO:my_logger:Log message 5872
# INFO:my_logger:Log message 5873
# INFO:my_logger:Log message 5874
# INFO:my_logger:Log message 5875
# INFO:my_logger:Log message 5876
# INFO:my_logger:Log message 5877
# INFO:my_logger:Log message 5878
# INFO:my_logger:Log message 5879
# INFO:my_logger:Log message 5880
# INFO:my_logger:Log message 5881
# INFO:my_logger:Log message 5882
# INFO:my_logger:Log message 5883
# INFO:my_logger:Log message 5884
# INFO:my_logger:Log message 5885
# INFO:my_logger:Log message 5886
# INFO:my_logger:Log message 5887
# INFO:my_logger:Log message 5888
# INFO:my_logger:Log message 5889
# INFO:my_logger:Log message 5890
# INFO:my_logger:Log message 5891
# INFO:my_logger:Log message 5892
# INFO:my_logger:Log message 5893
# INFO:my_logger:Log message 5894
# INFO:my_logger:Log message 5895
# INFO:my_logger:Log message 5896
# INFO:my_logger:Log message 5897
# INFO:my_logger:Log message 5898
# INFO:my_logger:Log message 5899
# INFO:my_logger:Log message 5900
# INFO:my_logger:Log message 5901
# INFO:my_logger:Log message 5902
# INFO:my_logger:Log message 5903
# INFO:my_logger:Log message 5904
# INFO:my_logger:Log message 5905
# INFO:my_logger:Log message 5906
# INFO:my_logger:Log message 5907
# INFO:my_logger:Log message 5908
# INFO:my_logger:Log message 5909
# INFO:my_logger:Log message 5910
# INFO:my_logger:Log message 5911
# INFO:my_logger:Log message 5912
# INFO:my_logger:Log message 5913
# INFO:my_logger:Log message 5914
# INFO:my_logger:Log message 5915
# INFO:my_logger:Log message 5916
# INFO:my_logger:Log message 5917
# INFO:my_logger:Log message 5918
# INFO:my_logger:Log message 5919
# INFO:my_logger:Log message 5920
# INFO:my_logger:Log message 5921
# INFO:my_logger:Log message 5922
# INFO:my_logger:Log message 5923
# INFO:my_logger:Log message 5924
# INFO:my_logger:Log message 5925
# INFO:my_logger:Log message 5926
# INFO:my_logger:Log message 5927
# INFO:my_logger:Log message 5928
# INFO:my_logger:Log message 5929
# INFO:my_logger:Log message 5930
# INFO:my_logger:Log message 5931
# INFO:my_logger:Log message 5932
# INFO:my_logger:Log message 5933
# INFO:my_logger:Log message 5934
# INFO:my_logger:Log message 5935
# INFO:my_logger:Log message 5936
# INFO:my_logger:Log message 5937
# INFO:my_logger:Log message 5938
# INFO:my_logger:Log message 5939
# INFO:my_logger:Log message 5940
# INFO:my_logger:Log message 5941
# INFO:my_logger:Log message 5942
# INFO:my_logger:Log message 5943
# INFO:my_logger:Log message 5944
# INFO:my_logger:Log message 5945
# INFO:my_logger:Log message 5946
# INFO:my_logger:Log message 5947
# INFO:my_logger:Log message 5948
# INFO:my_logger:Log message 5949
# INFO:my_logger:Log message 5950
# INFO:my_logger:Log message 5951
# INFO:my_logger:Log message 5952
# INFO:my_logger:Log message 5953
# INFO:my_logger:Log message 5954
# INFO:my_logger:Log message 5955
# INFO:my_logger:Log message 5956
# INFO:my_logger:Log message 5957
# INFO:my_logger:Log message 5958
# INFO:my_logger:Log message 5959
# INFO:my_logger:Log message 5960
# INFO:my_logger:Log message 5961
# INFO:my_logger:Log message 5962
# INFO:my_logger:Log message 5963
# INFO:my_logger:Log message 5964
# INFO:my_logger:Log message 5965
# INFO:my_logger:Log message 5966
# INFO:my_logger:Log message 5967
# INFO:my_logger:Log message 5968
# INFO:my_logger:Log message 5969
# INFO:my_logger:Log message 5970
# INFO:my_logger:Log message 5971
# INFO:my_logger:Log message 5972
# INFO:my_logger:Log message 5973
# INFO:my_logger:Log message 5974
# INFO:my_logger:Log message 5975
# INFO:my_logger:Log message 5976
# INFO:my_logger:Log message 5977
# INFO:my_logger:Log message 5978
# INFO:my_logger:Log message 5979
# INFO:my_logger:Log message 5980
# INFO:my_logger:Log message 5981
# INFO:my_logger:Log message 5982
# INFO:my_logger:Log message 5983
# INFO:my_logger:Log message 5984
# INFO:my_logger:Log message 5985
# INFO:my_logger:Log message 5986
# INFO:my_logger:Log message 5987
# INFO:my_logger:Log message 5988
# INFO:my_logger:Log message 5989
# INFO:my_logger:Log message 5990
# INFO:my_logger:Log message 5991
# INFO:my_logger:Log message 5992
# INFO:my_logger:Log message 5993
# INFO:my_logger:Log message 5994
# INFO:my_logger:Log message 5995
# INFO:my_logger:Log message 5996
# INFO:my_logger:Log message 5997
# INFO:my_logger:Log message 5998
# INFO:my_logger:Log message 5999
# INFO:my_logger:Log message 6000
# INFO:my_logger:Log message 6001
# INFO:my_logger:Log message 6002
# INFO:my_logger:Log message 6003
# INFO:my_logger:Log message 6004
# INFO:my_logger:Log message 6005
# INFO:my_logger:Log message 6006
# INFO:my_logger:Log message 6007
# INFO:my_logger:Log message 6008
# INFO:my_logger:Log message 6009
# INFO:my_logger:Log message 6010
# INFO:my_logger:Log message 6011
# INFO:my_logger:Log message 6012
# INFO:my_logger:Log message 6013
# INFO:my_logger:Log message 6014
# INFO:my_logger:Log message 6015
# INFO:my_logger:Log message 6016
# INFO:my_logger:Log message 6017
# INFO:my_logger:Log message 6018
# INFO:my_logger:Log message 6019
# INFO:my_logger:Log message 6020
# INFO:my_logger:Log message 6021
# INFO:my_logger:Log message 6022
# INFO:my_logger:Log message 6023
# INFO:my_logger:Log message 6024
# INFO:my_logger:Log message 6025
# INFO:my_logger:Log message 6026
# INFO:my_logger:Log message 6027
# INFO:my_logger:Log message 6028
# INFO:my_logger:Log message 6029
# INFO:my_logger:Log message 6030
# INFO:my_logger:Log message 6031
# INFO:my_logger:Log message 6032
# INFO:my_logger:Log message 6033
# INFO:my_logger:Log message 6034
# INFO:my_logger:Log message 6035
# INFO:my_logger:Log message 6036
# INFO:my_logger:Log message 6037
# INFO:my_logger:Log message 6038
# INFO:my_logger:Log message 6039
# INFO:my_logger:Log message 6040
# INFO:my_logger:Log message 6041
# INFO:my_logger:Log message 6042
# INFO:my_logger:Log message 6043
# INFO:my_logger:Log message 6044
# INFO:my_logger:Log message 6045
# INFO:my_logger:Log message 6046
# INFO:my_logger:Log message 6047
# INFO:my_logger:Log message 6048
# INFO:my_logger:Log message 6049
# INFO:my_logger:Log message 6050
# INFO:my_logger:Log message 6051
# INFO:my_logger:Log message 6052
# INFO:my_logger:Log message 6053
# INFO:my_logger:Log message 6054
# INFO:my_logger:Log message 6055
# INFO:my_logger:Log message 6056
# INFO:my_logger:Log message 6057
# INFO:my_logger:Log message 6058
# INFO:my_logger:Log message 6059
# INFO:my_logger:Log message 6060
# INFO:my_logger:Log message 6061
# INFO:my_logger:Log message 6062
# INFO:my_logger:Log message 6063
# INFO:my_logger:Log message 6064
# INFO:my_logger:Log message 6065
# INFO:my_logger:Log message 6066
# INFO:my_logger:Log message 6067
# INFO:my_logger:Log message 6068
# INFO:my_logger:Log message 6069
# INFO:my_logger:Log message 6070
# INFO:my_logger:Log message 6071
# INFO:my_logger:Log message 6072
# INFO:my_logger:Log message 6073
# INFO:my_logger:Log message 6074
# INFO:my_logger:Log message 6075
# INFO:my_logger:Log message 6076
# INFO:my_logger:Log message 6077
# INFO:my_logger:Log message 6078
# INFO:my_logger:Log message 6079
# INFO:my_logger:Log message 6080
# INFO:my_logger:Log message 6081
# INFO:my_logger:Log message 6082
# INFO:my_logger:Log message 6083
# INFO:my_logger:Log message 6084
# INFO:my_logger:Log message 6085
# INFO:my_logger:Log message 6086
# INFO:my_logger:Log message 6087
# INFO:my_logger:Log message 6088
# INFO:my_logger:Log message 6089
# INFO:my_logger:Log message 6090
# INFO:my_logger:Log message 6091
# INFO:my_logger:Log message 6092
# INFO:my_logger:Log message 6093
# INFO:my_logger:Log message 6094
# INFO:my_logger:Log message 6095
# INFO:my_logger:Log message 6096
# INFO:my_logger:Log message 6097
# INFO:my_logger:Log message 6098
# INFO:my_logger:Log message 6099
# INFO:my_logger:Log message 6100
# INFO:my_logger:Log message 6101
# INFO:my_logger:Log message 6102
# INFO:my_logger:Log message 6103
# INFO:my_logger:Log message 6104
# INFO:my_logger:Log message 6105
# INFO:my_logger:Log message 6106
# INFO:my_logger:Log message 6107
# INFO:my_logger:Log message 6108
# INFO:my_logger:Log message 6109
# INFO:my_logger:Log message 6110
# INFO:my_logger:Log message 6111
# INFO:my_logger:Log message 6112
# INFO:my_logger:Log message 6113
# INFO:my_logger:Log message 6114
# INFO:my_logger:Log message 6115
# INFO:my_logger:Log message 6116
# INFO:my_logger:Log message 6117
# INFO:my_logger:Log message 6118
# INFO:my_logger:Log message 6119
# INFO:my_logger:Log message 6120
# INFO:my_logger:Log message 6121
# INFO:my_logger:Log message 6122
# INFO:my_logger:Log message 6123
# INFO:my_logger:Log message 6124
# INFO:my_logger:Log message 6125
# INFO:my_logger:Log message 6126
# INFO:my_logger:Log message 6127
# INFO:my_logger:Log message 6128
# INFO:my_logger:Log message 6129
# INFO:my_logger:Log message 6130
# INFO:my_logger:Log message 6131
# INFO:my_logger:Log message 6132
# INFO:my_logger:Log message 6133
# INFO:my_logger:Log message 6134
# INFO:my_logger:Log message 6135
# INFO:my_logger:Log message 6136
# INFO:my_logger:Log message 6137
# INFO:my_logger:Log message 6138
# INFO:my_logger:Log message 6139
# INFO:my_logger:Log message 6140
# INFO:my_logger:Log message 6141
# INFO:my_logger:Log message 6142
# INFO:my_logger:Log message 6143
# INFO:my_logger:Log message 6144
# INFO:my_logger:Log message 6145
# INFO:my_logger:Log message 6146
# INFO:my_logger:Log message 6147
# INFO:my_logger:Log message 6148
# INFO:my_logger:Log message 6149
# INFO:my_logger:Log message 6150
# INFO:my_logger:Log message 6151
# INFO:my_logger:Log message 6152
# INFO:my_logger:Log message 6153
# INFO:my_logger:Log message 6154
# INFO:my_logger:Log message 6155
# INFO:my_logger:Log message 6156
# INFO:my_logger:Log message 6157
# INFO:my_logger:Log message 6158
# INFO:my_logger:Log message 6159
# INFO:my_logger:Log message 6160
# INFO:my_logger:Log message 6161
# INFO:my_logger:Log message 6162
# INFO:my_logger:Log message 6163
# INFO:my_logger:Log message 6164
# INFO:my_logger:Log message 6165
# INFO:my_logger:Log message 6166
# INFO:my_logger:Log message 6167
# INFO:my_logger:Log message 6168
# INFO:my_logger:Log message 6169
# INFO:my_logger:Log message 6170
# INFO:my_logger:Log message 6171
# INFO:my_logger:Log message 6172
# INFO:my_logger:Log message 6173
# INFO:my_logger:Log message 6174
# INFO:my_logger:Log message 6175
# INFO:my_logger:Log message 6176
# INFO:my_logger:Log message 6177
# INFO:my_logger:Log message 6178
# INFO:my_logger:Log message 6179
# INFO:my_logger:Log message 6180
# INFO:my_logger:Log message 6181
# INFO:my_logger:Log message 6182
# INFO:my_logger:Log message 6183
# INFO:my_logger:Log message 6184
# INFO:my_logger:Log message 6185
# INFO:my_logger:Log message 6186
# INFO:my_logger:Log message 6187
# INFO:my_logger:Log message 6188
# INFO:my_logger:Log message 6189
# INFO:my_logger:Log message 6190
# INFO:my_logger:Log message 6191
# INFO:my_logger:Log message 6192
# INFO:my_logger:Log message 6193
# INFO:my_logger:Log message 6194
# INFO:my_logger:Log message 6195
# INFO:my_logger:Log message 6196
# INFO:my_logger:Log message 6197
# INFO:my_logger:Log message 6198
# INFO:my_logger:Log message 6199
# INFO:my_logger:Log message 6200
# INFO:my_logger:Log message 6201
# INFO:my_logger:Log message 6202
# INFO:my_logger:Log message 6203
# INFO:my_logger:Log message 6204
# INFO:my_logger:Log message 6205
# INFO:my_logger:Log message 6206
# INFO:my_logger:Log message 6207
# INFO:my_logger:Log message 6208
# INFO:my_logger:Log message 6209
# INFO:my_logger:Log message 6210
# INFO:my_logger:Log message 6211
# INFO:my_logger:Log message 6212
# INFO:my_logger:Log message 6213
# INFO:my_logger:Log message 6214
# INFO:my_logger:Log message 6215
# INFO:my_logger:Log message 6216
# INFO:my_logger:Log message 6217
# INFO:my_logger:Log message 6218
# INFO:my_logger:Log message 6219
# INFO:my_logger:Log message 6220
# INFO:my_logger:Log message 6221
# INFO:my_logger:Log message 6222
# INFO:my_logger:Log message 6223
# INFO:my_logger:Log message 6224
# INFO:my_logger:Log message 6225
# INFO:my_logger:Log message 6226
# INFO:my_logger:Log message 6227
# INFO:my_logger:Log message 6228
# INFO:my_logger:Log message 6229
# INFO:my_logger:Log message 6230
# INFO:my_logger:Log message 6231
# INFO:my_logger:Log message 6232
# INFO:my_logger:Log message 6233
# INFO:my_logger:Log message 6234
# INFO:my_logger:Log message 6235
# INFO:my_logger:Log message 6236
# INFO:my_logger:Log message 6237
# INFO:my_logger:Log message 6238
# INFO:my_logger:Log message 6239
# INFO:my_logger:Log message 6240
# INFO:my_logger:Log message 6241
# INFO:my_logger:Log message 6242
# INFO:my_logger:Log message 6243
# INFO:my_logger:Log message 6244
# INFO:my_logger:Log message 6245
# INFO:my_logger:Log message 6246
# INFO:my_logger:Log message 6247
# INFO:my_logger:Log message 6248
# INFO:my_logger:Log message 6249
# INFO:my_logger:Log message 6250
# INFO:my_logger:Log message 6251
# INFO:my_logger:Log message 6252
# INFO:my_logger:Log message 6253
# INFO:my_logger:Log message 6254
# INFO:my_logger:Log message 6255
# INFO:my_logger:Log message 6256
# INFO:my_logger:Log message 6257
# INFO:my_logger:Log message 6258
# INFO:my_logger:Log message 6259
# INFO:my_logger:Log message 6260
# INFO:my_logger:Log message 6261
# INFO:my_logger:Log message 6262
# INFO:my_logger:Log message 6263
# INFO:my_logger:Log message 6264
# INFO:my_logger:Log message 6265
# INFO:my_logger:Log message 6266
# INFO:my_logger:Log message 6267
# INFO:my_logger:Log message 6268
# INFO:my_logger:Log message 6269
# INFO:my_logger:Log message 6270
# INFO:my_logger:Log message 6271
# INFO:my_logger:Log message 6272
# INFO:my_logger:Log message 6273
# INFO:my_logger:Log message 6274
# INFO:my_logger:Log message 6275
# INFO:my_logger:Log message 6276
# INFO:my_logger:Log message 6277
# INFO:my_logger:Log message 6278
# INFO:my_logger:Log message 6279
# INFO:my_logger:Log message 6280
# INFO:my_logger:Log message 6281
# INFO:my_logger:Log message 6282
# INFO:my_logger:Log message 6283
# INFO:my_logger:Log message 6284
# INFO:my_logger:Log message 6285
# INFO:my_logger:Log message 6286
# INFO:my_logger:Log message 6287
# INFO:my_logger:Log message 6288
# INFO:my_logger:Log message 6289
# INFO:my_logger:Log message 6290
# INFO:my_logger:Log message 6291
# INFO:my_logger:Log message 6292
# INFO:my_logger:Log message 6293
# INFO:my_logger:Log message 6294
# INFO:my_logger:Log message 6295
# INFO:my_logger:Log message 6296
# INFO:my_logger:Log message 6297
# INFO:my_logger:Log message 6298
# INFO:my_logger:Log message 6299
# INFO:my_logger:Log message 6300
# INFO:my_logger:Log message 6301
# INFO:my_logger:Log message 6302
# INFO:my_logger:Log message 6303
# INFO:my_logger:Log message 6304
# INFO:my_logger:Log message 6305
# INFO:my_logger:Log message 6306
# INFO:my_logger:Log message 6307
# INFO:my_logger:Log message 6308
# INFO:my_logger:Log message 6309
# INFO:my_logger:Log message 6310
# INFO:my_logger:Log message 6311
# INFO:my_logger:Log message 6312
# INFO:my_logger:Log message 6313
# INFO:my_logger:Log message 6314
# INFO:my_logger:Log message 6315
# INFO:my_logger:Log message 6316
# INFO:my_logger:Log message 6317
# INFO:my_logger:Log message 6318
# INFO:my_logger:Log message 6319
# INFO:my_logger:Log message 6320
# INFO:my_logger:Log message 6321
# INFO:my_logger:Log message 6322
# INFO:my_logger:Log message 6323
# INFO:my_logger:Log message 6324
# INFO:my_logger:Log message 6325
# INFO:my_logger:Log message 6326
# INFO:my_logger:Log message 6327
# INFO:my_logger:Log message 6328
# INFO:my_logger:Log message 6329
# INFO:my_logger:Log message 6330
# INFO:my_logger:Log message 6331
# INFO:my_logger:Log message 6332
# INFO:my_logger:Log message 6333
# INFO:my_logger:Log message 6334
# INFO:my_logger:Log message 6335
# INFO:my_logger:Log message 6336
# INFO:my_logger:Log message 6337
# INFO:my_logger:Log message 6338
# INFO:my_logger:Log message 6339
# INFO:my_logger:Log message 6340
# INFO:my_logger:Log message 6341
# INFO:my_logger:Log message 6342
# INFO:my_logger:Log message 6343
# INFO:my_logger:Log message 6344
# INFO:my_logger:Log message 6345
# INFO:my_logger:Log message 6346
# INFO:my_logger:Log message 6347
# INFO:my_logger:Log message 6348
# INFO:my_logger:Log message 6349
# INFO:my_logger:Log message 6350
# INFO:my_logger:Log message 6351
# INFO:my_logger:Log message 6352
# INFO:my_logger:Log message 6353
# INFO:my_logger:Log message 6354
# INFO:my_logger:Log message 6355
# INFO:my_logger:Log message 6356
# INFO:my_logger:Log message 6357
# INFO:my_logger:Log message 6358
# INFO:my_logger:Log message 6359
# INFO:my_logger:Log message 6360
# INFO:my_logger:Log message 6361
# INFO:my_logger:Log message 6362
# INFO:my_logger:Log message 6363
# INFO:my_logger:Log message 6364
# INFO:my_logger:Log message 6365
# INFO:my_logger:Log message 6366
# INFO:my_logger:Log message 6367
# INFO:my_logger:Log message 6368
# INFO:my_logger:Log message 6369
# INFO:my_logger:Log message 6370
# INFO:my_logger:Log message 6371
# INFO:my_logger:Log message 6372
# INFO:my_logger:Log message 6373
# INFO:my_logger:Log message 6374
# INFO:my_logger:Log message 6375
# INFO:my_logger:Log message 6376
# INFO:my_logger:Log message 6377
# INFO:my_logger:Log message 6378
# INFO:my_logger:Log message 6379
# INFO:my_logger:Log message 6380
# INFO:my_logger:Log message 6381
# INFO:my_logger:Log message 6382
# INFO:my_logger:Log message 6383
# INFO:my_logger:Log message 6384
# INFO:my_logger:Log message 6385
# INFO:my_logger:Log message 6386
# INFO:my_logger:Log message 6387
# INFO:my_logger:Log message 6388
# INFO:my_logger:Log message 6389
# INFO:my_logger:Log message 6390
# INFO:my_logger:Log message 6391
# INFO:my_logger:Log message 6392
# INFO:my_logger:Log message 6393
# INFO:my_logger:Log message 6394
# INFO:my_logger:Log message 6395
# INFO:my_logger:Log message 6396
# INFO:my_logger:Log message 6397
# INFO:my_logger:Log message 6398
# INFO:my_logger:Log message 6399
# INFO:my_logger:Log message 6400
# INFO:my_logger:Log message 6401
# INFO:my_logger:Log message 6402
# INFO:my_logger:Log message 6403
# INFO:my_logger:Log message 6404
# INFO:my_logger:Log message 6405
# INFO:my_logger:Log message 6406
# INFO:my_logger:Log message 6407
# INFO:my_logger:Log message 6408
# INFO:my_logger:Log message 6409
# INFO:my_logger:Log message 6410
# INFO:my_logger:Log message 6411
# INFO:my_logger:Log message 6412
# INFO:my_logger:Log message 6413
# INFO:my_logger:Log message 6414
# INFO:my_logger:Log message 6415
# INFO:my_logger:Log message 6416
# INFO:my_logger:Log message 6417
# INFO:my_logger:Log message 6418
# INFO:my_logger:Log message 6419
# INFO:my_logger:Log message 6420
# INFO:my_logger:Log message 6421
# INFO:my_logger:Log message 6422
# INFO:my_logger:Log message 6423
# INFO:my_logger:Log message 6424
# INFO:my_logger:Log message 6425
# INFO:my_logger:Log message 6426
# INFO:my_logger:Log message 6427
# INFO:my_logger:Log message 6428
# INFO:my_logger:Log message 6429
# INFO:my_logger:Log message 6430
# INFO:my_logger:Log message 6431
# INFO:my_logger:Log message 6432
# INFO:my_logger:Log message 6433
# INFO:my_logger:Log message 6434
# INFO:my_logger:Log message 6435
# INFO:my_logger:Log message 6436
# INFO:my_logger:Log message 6437
# INFO:my_logger:Log message 6438
# INFO:my_logger:Log message 6439
# INFO:my_logger:Log message 6440
# INFO:my_logger:Log message 6441
# INFO:my_logger:Log message 6442
# INFO:my_logger:Log message 6443
# INFO:my_logger:Log message 6444
# INFO:my_logger:Log message 6445
# INFO:my_logger:Log message 6446
# INFO:my_logger:Log message 6447
# INFO:my_logger:Log message 6448
# INFO:my_logger:Log message 6449
# INFO:my_logger:Log message 6450
# INFO:my_logger:Log message 6451
# INFO:my_logger:Log message 6452
# INFO:my_logger:Log message 6453
# INFO:my_logger:Log message 6454
# INFO:my_logger:Log message 6455
# INFO:my_logger:Log message 6456
# INFO:my_logger:Log message 6457
# INFO:my_logger:Log message 6458
# INFO:my_logger:Log message 6459
# INFO:my_logger:Log message 6460
# INFO:my_logger:Log message 6461
# INFO:my_logger:Log message 6462
# INFO:my_logger:Log message 6463
# INFO:my_logger:Log message 6464
# INFO:my_logger:Log message 6465
# INFO:my_logger:Log message 6466
# INFO:my_logger:Log message 6467
# INFO:my_logger:Log message 6468
# INFO:my_logger:Log message 6469
# INFO:my_logger:Log message 6470
# INFO:my_logger:Log message 6471
# INFO:my_logger:Log message 6472
# INFO:my_logger:Log message 6473
# INFO:my_logger:Log message 6474
# INFO:my_logger:Log message 6475
# INFO:my_logger:Log message 6476
# INFO:my_logger:Log message 6477
# INFO:my_logger:Log message 6478
# INFO:my_logger:Log message 6479
# INFO:my_logger:Log message 6480
# INFO:my_logger:Log message 6481
# INFO:my_logger:Log message 6482
# INFO:my_logger:Log message 6483
# INFO:my_logger:Log message 6484
# INFO:my_logger:Log message 6485
# INFO:my_logger:Log message 6486
# INFO:my_logger:Log message 6487
# INFO:my_logger:Log message 6488
# INFO:my_logger:Log message 6489
# INFO:my_logger:Log message 6490
# INFO:my_logger:Log message 6491
# INFO:my_logger:Log message 6492
# INFO:my_logger:Log message 6493
# INFO:my_logger:Log message 6494
# INFO:my_logger:Log message 6495
# INFO:my_logger:Log message 6496
# INFO:my_logger:Log message 6497
# ...
# INFO:my_logger:Log message 9500
# INFO:my_logger:Log message 9501
# INFO:my_logger:Log message 9502
# INFO:my_logger:Log message 9503
# INFO:my_logger:Log message 9504
# INFO:my_logger:Log message 9505
# INFO:my_logger:Log message 9506
# INFO:my_logger:Log message 9507
# INFO:my_logger:Log message 9508
# INFO:my_logger:Log message 9509
# INFO:my_logger:Log message 9510
# INFO:my_logger:Log message 9511
# INFO:my_logger:Log message 9512
# INFO:my_logger:Log message 9513
# INFO:my_logger:Log message 9514
# INFO:my_logger:Log message 9515
# INFO:my_logger:Log message 9516
# INFO:my_logger:Log message 9517
# INFO:my_logger:Log message 9518
# INFO:my_logger:Log message 9519
# INFO:my_logger:Log message 9520
# INFO:my_logger:Log message 9521
# INFO:my_logger:Log message 9522
# INFO:my_logger:Log message 9523
# INFO:my_logger:Log message 9524
# INFO:my_logger:Log message 9525
# INFO:my_logger:Log message 9526
# INFO:my_logger:Log message 9527
# INFO:my_logger:Log message 9528
# INFO:my_logger:Log message 9529
# INFO:my_logger:Log message 9530
# INFO:my_logger:Log message 9531
# INFO:my_logger:Log message 9532
# INFO:my_logger:Log message 9533
# INFO:my_logger:Log message 9534
# INFO:my_logger:Log message 9535
# INFO:my_logger:Log message 9536
# INFO:my_logger:Log message 9537
# INFO:my_logger:Log message 9538
# INFO:my_logger:Log message 9539
# INFO:my_logger:Log message 9540
# INFO:my_logger:Log message 9541
# INFO:my_logger:Log message 9542
# INFO:my_logger:Log message 9543
# INFO:my_logger:Log message 9544
# INFO:my_logger:Log message 9545
# INFO:my_logger:Log message 9546
# INFO:my_logger:Log message 9547
# INFO:my_logger:Log message 9548
# INFO:my_logger:Log message 9549
# INFO:my_logger:Log message 9550
# INFO:my_logger:Log message 9551
# INFO:my_logger:Log message 9552
# INFO:my_logger:Log message 9553
# INFO:my_logger:Log message 9554
# INFO:my_logger:Log message 9555
# INFO:my_logger:Log message 9556
# INFO:my_logger:Log message 9557
# INFO:my_logger:Log message 9558
# INFO:my_logger:Log message 9559
# INFO:my_logger:Log message 9560
# INFO:my_logger:Log message 9561
# INFO:my_logger:Log message 9562
# INFO:my_logger:Log message 9563
# INFO:my_logger:Log message 9564
# INFO:my_logger:Log message 9565
# INFO:my_logger:Log message 9566
# INFO:my_logger:Log message 9567
# INFO:my_logger:Log message 9568
# INFO:my_logger:Log message 9569
# INFO:my_logger:Log message 9570
# INFO:my_logger:Log message 9571
# INFO:my_logger:Log message 9572
# INFO:my_logger:Log message 9573
# INFO:my_logger:Log message 9574
# INFO:my_logger:Log message 9575
# INFO:my_logger:Log message 9576
# INFO:my_logger:Log message 9577
# INFO:my_logger:Log message 9578
# INFO:my_logger:Log message 9579
# INFO:my_logger:Log message 9580
# INFO:my_logger:Log message 9581
# INFO:my_logger:Log message 9582
# INFO:my_logger:Log message 9583
# INFO:my_logger:Log message 9584
# INFO:my_logger:Log message 9585
# INFO:my_logger:Log message 9586
# INFO:my_logger:Log message 9587
# INFO:my_logger:Log message 9588
# INFO:my_logger:Log message 9589
# INFO:my_logger:Log message 9590
# INFO:my_logger:Log message 9591
# INFO:my_logger:Log message 9592
# INFO:my_logger:Log message 9593
# INFO:my_logger:Log message 9594
# INFO:my_logger:Log message 9595
# INFO:my_logger:Log message 9596
# INFO:my_logger:Log message 9597
# INFO:my_logger:Log message 9598
# INFO:my_logger:Log message 9599
# INFO:my_logger:Log message 9600
# INFO:my_logger:Log message 9601
# INFO:my_logger:Log message 9602
# INFO:my_logger:Log message 9603
# INFO:my_logger:Log message 9604
# INFO:my_logger:Log message 9605
# INFO:my_logger:Log message 9606
# INFO:my_logger:Log message 9607
# INFO:my_logger:Log message 9608
# INFO:my_logger:Log message 9609
# INFO:my_logger:Log message 9610
# INFO:my_logger:Log message 9611
# INFO:my_logger:Log message 9612
# INFO:my_logger:Log message 9613
# INFO:my_logger:Log message 9614
# INFO:my_logger:Log message 9615
# INFO:my_logger:Log message 9616
# INFO:my_logger:Log message 9617
# INFO:my_logger:Log message 9618
# INFO:my_logger:Log message 9619
# INFO:my_logger:Log message 9620
# INFO:my_logger:Log message 9621
# INFO:my_logger:Log message 9622
# INFO:my_logger:Log message 9623
# INFO:my_logger:Log message 9624
# INFO:my_logger:Log message 9625
# INFO:my_logger:Log message 9626
# INFO:my_logger:Log message 9627
# INFO:my_logger:Log message 9628
# INFO:my_logger:Log message 9629
# INFO:my_logger:Log message 9630
# INFO:my_logger:Log message 9631
# INFO:my_logger:Log message 9632
# INFO:my_logger:Log message 9633
# INFO:my_logger:Log message 9634
# INFO:my_logger:Log message 9635
# INFO:my_logger:Log message 9636
# INFO:my_logger:Log message 9637
# INFO:my_logger:Log message 9638
# INFO:my_logger:Log message 9639
# INFO:my_logger:Log message 9640
# INFO:my_logger:Log message 9641
# INFO:my_logger:Log message 9642
# INFO:my_logger:Log message 9643
# INFO:my_logger:Log message 9644
# INFO:my_logger:Log message 9645
# INFO:my_logger:Log message 9646
# INFO:my_logger:Log message 9647
# INFO:my_logger:Log message 9648
# INFO:my_logger:Log message 9649
# INFO:my_logger:Log message 9650
# INFO:my_logger:Log message 9651
# INFO:my_logger:Log message 9652
# INFO:my_logger:Log message 9653
# INFO:my_logger:Log message 9654
# INFO:my_logger:Log message 9655
# INFO:my_logger:Log message 9656
# INFO:my_logger:Log message 9657
# INFO:my_logger:Log message 9658
# INFO:my_logger:Log message 9659
# INFO:my_logger:Log message 9660
# INFO:my_logger:Log message 9661
# INFO:my_logger:Log message 9662
# INFO:my_logger:Log message 9663
# INFO:my_logger:Log message 9664
# INFO:my_logger:Log message 9665
# INFO:my_logger:Log message 9666
# INFO:my_logger:Log message 9667
# INFO:my_logger:Log message 9668
# INFO:my_logger:Log message 9669
# INFO:my_logger:Log message 9670
# INFO:my_logger:Log message 9671
# INFO:my_logger:Log message 9672
# INFO:my_logger:Log message 9673
# INFO:my_logger:Log message 9674
# INFO:my_logger:Log message 9675
# INFO:my_logger:Log message 9676
# INFO:my_logger:Log message 9677
# INFO:my_logger:Log message 9678
# INFO:my_logger:Log message 9679
# INFO:my_logger:Log message 9680
# INFO:my_logger:Log message 9681
# INFO:my_logger:Log message 9682
# INFO:my_logger:Log message 9683
# INFO:my_logger:Log message 9684
# INFO:my_logger:Log message 9685
# INFO:my_logger:Log message 9686
# INFO:my_logger:Log message 9687
# INFO:my_logger:Log message 9688
# INFO:my_logger:Log message 9689
# INFO:my_logger:Log message 9690
# INFO:my_logger:Log message 9691
# INFO:my_logger:Log message 9692
# INFO:my_logger:Log message 9693
# INFO:my_logger:Log message 9694
# INFO:my_logger:Log message 9695
# INFO:my_logger:Log message 9696
# INFO:my_logger:Log message 9697
# INFO:my_logger:Log message 9698
# INFO:my_logger:Log message 9699
# INFO:my_logger:Log message 9700
# INFO:my_logger:Log message 9701
# INFO:my_logger:Log message 9702
# INFO:my_logger:Log message 9703
# INFO:my_logger:Log message 9704
# INFO:my_logger:Log message 9705
# INFO:my_logger:Log message 9706
# INFO:my_logger:Log message 9707
# INFO:my_logger:Log message 9708
# INFO:my_logger:Log message 9709
# INFO:my_logger:Log message 9710
# INFO:my_logger:Log message 9711
# INFO:my_logger:Log message 9712
# INFO:my_logger:Log message 9713
# INFO:my_logger:Log message 9714
# INFO:my_logger:Log message 9715
# INFO:my_logger:Log message 9716
# INFO:my_logger:Log message 9717
# INFO:my_logger:Log message 9718
# INFO:my_logger:Log message 9719
# INFO:my_logger:Log message 9720
# INFO:my_logger:Log message 9721
# INFO:my_logger:Log message 9722
# INFO:my_logger:Log message 9723
# INFO:my_logger:Log message 9724
# INFO:my_logger:Log message 9725
# INFO:my_logger:Log message 9726
# INFO:my_logger:Log message 9727
# INFO:my_logger:Log message 9728
# INFO:my_logger:Log message 9729
# INFO:my_logger:Log message 9730
# INFO:my_logger:Log message 9731
# INFO:my_logger:Log message 9732
# INFO:my_logger:Log message 9733
# INFO:my_logger:Log message 9734
# INFO:my_logger:Log message 9735
# INFO:my_logger:Log message 9736
# INFO:my_logger:Log message 9737
# INFO:my_logger:Log message 9738
# INFO:my_logger:Log message 9739
# INFO:my_logger:Log message 9740
# INFO:my_logger:Log message 9741
# INFO:my_logger:Log message 9742
# INFO:my_logger:Log message 9743
# INFO:my_logger:Log message 9744
# INFO:my_logger:Log message 9745
# INFO:my_logger:Log message 9746
# INFO:my_logger:Log message 9747
# INFO:my_logger:Log message 9748
# INFO:my_logger:Log message 9749
# INFO:my_logger:Log message 9750
# INFO:my_logger:Log message 9751
# INFO:my_logger:Log message 9752
# INFO:my_logger:Log message 9753
# INFO:my_logger:Log message 9754
# INFO:my_logger:Log message 9755
# INFO:my_logger:Log message 9756
# INFO:my_logger:Log message 9757
# INFO:my_logger:Log message 9758
# INFO:my_logger:Log message 9759
# INFO:my_logger:Log message 9760
# INFO:my_logger:Log message 9761
# INFO:my_logger:Log message 9762
# INFO:my_logger:Log message 9763
# INFO:my_logger:Log message 9764
# INFO:my_logger:Log message 9765
# INFO:my_logger:Log message 9766
# INFO:my_logger:Log message 9767
# INFO:my_logger:Log message 9768
# INFO:my_logger:Log message 9769
# INFO:my_logger:Log message 9770
# INFO:my_logger:Log message 9771
# INFO:my_logger:Log message 9772
# INFO:my_logger:Log message 9773
# INFO:my_logger:Log message 9774
# INFO:my_logger:Log message 9775
# INFO:my_logger:Log message 9776
# INFO:my_logger:Log message 9777
# INFO:my_logger:Log message 9778
# INFO:my_logger:Log message 9779
# INFO:my_logger:Log message 9780
# INFO:my_logger:Log message 9781
# INFO:my_logger:Log message 9782
# INFO:my_logger:Log message 9783
# INFO:my_logger:Log message 9784
# INFO:my_logger:Log message 9785
# INFO:my_logger:Log message 9786
# INFO:my_logger:Log message 9787
# INFO:my_logger:Log message 9788
# INFO:my_logger:Log message 9789
# INFO:my_logger:Log message 9790
# INFO:my_logger:Log message 9791
# INFO:my_logger:Log message 9792
# INFO:my_logger:Log message 9793
# INFO:my_logger:Log message 9794
# INFO:my_logger:Log message 9795
# INFO:my_logger:Log message 9796
# INFO:my_logger:Log message 9797
# INFO:my_logger:Log message 9798
# INFO:my_logger:Log message 9799
# INFO:my_logger:Log message 9800
# INFO:my_logger:Log message 9801
# INFO:my_logger:Log message 9802
# INFO:my_logger:Log message 9803
# INFO:my_logger:Log message 9804
# INFO:my_logger:Log message 9805
# INFO:my_logger:Log message 9806
# INFO:my_logger:Log message 9807
# INFO:my_logger:Log message 9808
# INFO:my_logger:Log message 9809
# INFO:my_logger:Log message 9810
# INFO:my_logger:Log message 9811
# INFO:my_logger:Log message 9812
# INFO:my_logger:Log message 9813
# INFO:my_logger:Log message 9814
# INFO:my_logger:Log message 9815
# INFO:my_logger:Log message 9816
# INFO:my_logger:Log message 9817
# INFO:my_logger:Log message 9818
# INFO:my_logger:Log message 9819
# INFO:my_logger:Log message 9820
# INFO:my_logger:Log message 9821
# INFO:my_logger:Log message 9822
# INFO:my_logger:Log message 9823
# INFO:my_logger:Log message 9824
# INFO:my_logger:Log message 9825
# INFO:my_logger:Log message 9826
# INFO:my_logger:Log message 9827
# INFO:my_logger:Log message 9828
# INFO:my_logger:Log message 9829
# INFO:my_logger:Log message 9830
# INFO:my_logger:Log message 9831
# INFO:my_logger:Log message 9832
# INFO:my_logger:Log message 9833
# INFO:my_logger:Log message 9834
# INFO:my_logger:Log message 9835
# INFO:my_logger:Log message 9836
# INFO:my_logger:Log message 9837
# INFO:my_logger:Log message 9838
# INFO:my_logger:Log message 9839
# INFO:my_logger:Log message 9840
# INFO:my_logger:Log message 9841
# INFO:my_logger:Log message 9842
# INFO:my_logger:Log message 9843
# INFO:my_logger:Log message 9844
# INFO:my_logger:Log message 9845
# INFO:my_logger:Log message 9846
# INFO:my_logger:Log message 9847
# INFO:my_logger:Log message 9848
# INFO:my_logger:Log message 9849
# INFO:my_logger:Log message 9850
# INFO:my_logger:Log message 9851
# INFO:my_logger:Log message 9852
# INFO:my_logger:Log message 9853
# INFO:my_logger:Log message 9854
# INFO:my_logger:Log message 9855
# INFO:my_logger:Log message 9856
# INFO:my_logger:Log message 9857
# INFO:my_logger:Log message 9858
# INFO:my_logger:Log message 9859
# INFO:my_logger:Log message 9860
# INFO:my_logger:Log message 9861
# INFO:my_logger:Log message 9862
# INFO:my_logger:Log message 9863
# INFO:my_logger:Log message 9864
# INFO:my_logger:Log message 9865
# INFO:my_logger:Log message 9866
# INFO:my_logger:Log message 9867
# INFO:my_logger:Log message 9868
# INFO:my_logger:Log message 9869
# INFO:my_logger:Log message 9870
# INFO:my_logger:Log message 9871
# INFO:my_logger:Log message 9872
# INFO:my_logger:Log message 9873
# INFO:my_logger:Log message 9874
# INFO:my_logger:Log message 9875
# INFO:my_logger:Log message 9876
# INFO:my_logger:Log message 9877
# INFO:my_logger:Log message 9878
# INFO:my_logger:Log message 9879
# INFO:my_logger:Log message 9880
# INFO:my_logger:Log message 9881
# INFO:my_logger:Log message 9882
# INFO:my_logger:Log message 9883
# INFO:my_logger:Log message 9884
# INFO:my_logger:Log message 9885
# INFO:my_logger:Log message 9886
# INFO:my_logger:Log message 9887
# INFO:my_logger:Log message 9888
# INFO:my_logger:Log message 9889
# INFO:my_logger:Log message 9890
# INFO:my_logger:Log message 9891
# INFO:my_logger:Log message 9892
# INFO:my_logger:Log message 9893
# INFO:my_logger:Log message 9894
# INFO:my_logger:Log message 9895
# INFO:my_logger:Log message 9896
# INFO:my_logger:Log message 9897
# INFO:my_logger:Log message 9898
# INFO:my_logger:Log message 9899
# INFO:my_logger:Log message 9900
# INFO:my_logger:Log message 9901
# INFO:my_logger:Log message 9902
# INFO:my_logger:Log message 9903
# INFO:my_logger:Log message 9904
# INFO:my_logger:Log message 9905
# INFO:my_logger:Log message 9906
# INFO:my_logger:Log message 9907
# INFO:my_logger:Log message 9908
# INFO:my_logger:Log message 9909
# INFO:my_logger:Log message 9910
# INFO:my_logger:Log message 9911
# INFO:my_logger:Log message 9912
# INFO:my_logger:Log message 9913
# INFO:my_logger:Log message 9914
# INFO:my_logger:Log message 9915
# INFO:my_logger:Log message 9916
# INFO:my_logger:Log message 9917
# INFO:my_logger:Log message 9918
# INFO:my_logger:Log message 9919
# INFO:my_logger:Log message 9920
# INFO:my_logger:Log message 9921
# INFO:my_logger:Log message 9922
# INFO:my_logger:Log message 9923
# INFO:my_logger:Log message 9924
# INFO:my_logger:Log message 9925
# INFO:my_logger:Log message 9926
# INFO:my_logger:Log message 9927
# INFO:my_logger:Log message 9928
# INFO:my_logger:Log message 9929
# INFO:my_logger:Log message 9930
# INFO:my_logger:Log message 9931
# INFO:my_logger:Log message 9932
# INFO:my_logger:Log message 9933
# INFO:my_logger:Log message 9934
# INFO:my_logger:Log message 9935
# INFO:my_logger:Log message 9936
# INFO:my_logger:Log message 9937
# INFO:my_logger:Log message 9938
# INFO:my_logger:Log message 9939
# INFO:my_logger:Log message 9940
# INFO:my_logger:Log message 9941
# INFO:my_logger:Log message 9942
# INFO:my_logger:Log message 9943
# INFO:my_logger:Log message 9944
# INFO:my_logger:Log message 9945
# INFO:my_logger:Log message 9946
# INFO:my_logger:Log message 9947
# INFO:my_logger:Log message 9948
# INFO:my_logger:Log message 9949
# INFO:my_logger:Log message 9950
# INFO:my_logger:Log message 9951
# INFO:my_logger:Log message 9952
# INFO:my_logger:Log message 9953
# INFO:my_logger:Log message 9954
# INFO:my_logger:Log message 9955
# INFO:my_logger:Log message 9956
# INFO:my_logger:Log message 9957
# INFO:my_logger:Log message 9958
# INFO:my_logger:Log message 9959
# INFO:my_logger:Log message 9960
# INFO:my_logger:Log message 9961
# INFO:my_logger:Log message 9962
# INFO:my_logger:Log message 9963
# INFO:my_logger:Log message 9964
# INFO:my_logger:Log message 9965
# INFO:my_logger:Log message 9966
# INFO:my_logger:Log message 9967
# INFO:my_logger:Log message 9968
# INFO:my_logger:Log message 9969
# INFO:my_logger:Log message 9970
# INFO:my_logger:Log message 9971
# INFO:my_logger:Log message 9972
# INFO:my_logger:Log message 9973
# INFO:my_logger:Log message 9974
# INFO:my_logger:Log message 9975
# INFO:my_logger:Log message 9976
# INFO:my_logger:Log message 9977
# INFO:my_logger:Log message 9978
# INFO:my_logger:Log message 9979
# INFO:my_logger:Log message 9980
# INFO:my_logger:Log message 9981
# INFO:my_logger:Log message 9982
# INFO:my_logger:Log message 9983
# INFO:my_logger:Log message 9984
# INFO:my_logger:Log message 9985
# INFO:my_logger:Log message 9986
# INFO:my_logger:Log message 9987
# INFO:my_logger:Log message 9988
# INFO:my_logger:Log message 9989
# INFO:my_logger:Log message 9990
# INFO:my_logger:Log message 9991
# INFO:my_logger:Log message 9992
# INFO:my_logger:Log message 9993
# INFO:my_logger:Log message 9994
# INFO:my_logger:Log message 9995
# INFO:my_logger:Log message 9996
# INFO:my_logger:Log message 9997
# INFO:my_logger:Log message 9998
# INFO:my_logger:Log message 9999

# %% [markdown]
# ### **19. Write a program that handles both IndexError and KeyError using a try-except block.**

# %%
try:
    lst = [1, 2, 3]
    print(lst[5])
    d = {"a": 1}
    print(d["b"])
except IndexError:
    print("List index out of range")
except KeyError:
    print("Key not found in dictionary")
# Out:
# List index out of range

# %% [markdown]
# ### **20. How would you open a file and read its contents using a context manager in Python?**
#
# **Answer:**
#
# This is the most common and recommended way, using the `with` statement.

# %%
# Create a dummy file
with open("context_manager_example.txt", "w") as f:
    f.write("This file was opened using a context manager.\n")
    f.write("It ensures the file is automatically closed.")

try:
    # Open the file using a context manager
    with open("context_manager_example.txt", "r") as file:
        content = file.read()
        print("File content read successfully:")
        print(content)
    # The file is automatically closed here, even if errors occurred inside the 'with' block
    print("\nFile 'context_manager_example.txt' is now closed.")

except FileNotFoundError:
    print("Error: File not found.")
except IOError as e:
    print(f"An I/O error occurred: {e}")
# Out:
# File content read successfully:
# This file was opened using a context manager.
# It ensures the file is automatically closed.
#
# File 'context_manager_example.txt' is now closed.

# %% [markdown]
# ### **21. Write a Python program that reads a file and prints the number of occurrences of a specific word.**

# %%
def count_word_occurrences(filename, word_to_find):
    count = 0
    word_to_find_lower = word_to_find.lower() # Case-insensitive search
    try:
        with open(filename, "r") as file:
            for line in file:
                # Split line into words and convert to lowercase for case-insensitive comparison
                words_in_line = line.lower().split()
                count += words_in_line.count(word_to_find_lower)
        print(f"The word '{word_to_find}' appears {count} times in '{filename}'.")
        return count
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
        return -1
    except IOError as e:
        print(f"An I/O error occurred while reading '{filename}': {e}")
        return -1

# Create a dummy file
with open("word_search_test.txt", "w") as f:
    f.write("Python is a powerful language. Python is versatile.\n")
    f.write("Learn Python to become a great programmer. python.\n")
    f.write("Python IDEs are great.")

print("--- Searching for 'Python' ---")
count_word_occurrences("word_search_test.txt", "Python")

print("\n--- Searching for 'is' ---")
count_word_occurrences("word_search_test.txt", "is")

print("\n--- Searching for a non-existent word ---")
count_word_occurrences("word_search_test.txt", "java")

print("\n--- Searching in a non-existent file ---")
count_word_occurrences("non_existent_word_file.txt", "test")
# Out:
# --- Searching for 'Python' ---
# The word 'Python' appears 4 times in 'word_search_test.txt'.
#
# --- Searching for 'is' ---
# The word 'is' appears 2 times in 'word_search_test.txt'.
#
# --- Searching for a non-existent word ---
# The word 'java' appears 0 times in 'word_search_test.txt'.
#
# --- Searching in a non-existent file ---
# Error: The file 'non_existent_word_file.txt' was not found.
# -1

# %% [markdown]
# ### **22. How can you check if a file is empty before attempting to read its contents?**
#
# **Answer:**
#
# You can check a file's size using `os.path.getsize()`. If it returns 0, the file is empty.

# %%
import os

def check_and_read_file(filename):
    if not os.path.exists(filename):
        print(f"Error: The file '{filename}' does not exist.")
        return

    try:
        if os.path.getsize(filename) == 0:
            print(f"The file '{filename}' is empty.")
        else:
            print(f"The file '{filename}' is not empty. Reading content:")
            with open(filename, "r") as f:
                print(f.read())
    except OSError as e: # Catches various OS-related errors like permission issues
        print(f"Error accessing file '{filename}': {e}")

# Create dummy files
with open("non_empty_check.txt", "w") as f:
    f.write("Some content here.")
with open("empty_check.txt", "w") as f:
    pass # Creates an empty file

print("--- Checking non_empty_check.txt ---")
check_and_read_file("non_empty_check.txt")

print("\n--- Checking empty_check.txt ---")
check_and_read_file("empty_check.txt")

print("\n--- Checking non_existent_file_check.txt ---")
check_and_read_file("non_existent_file_check.txt")
# Out:
# --- Checking non_empty_check.txt ---
# The file 'non_empty_check.txt' is not empty. Reading content:
# Some content here.
#
# --- Checking empty_check.txt ---
# The file 'empty_check.txt' is empty.
#
# --- Checking non_existent_file_check.txt ---
# Error: The file 'non_existent_file_check.txt' does not exist.

# %% [markdown]
# ### **23. Write a Python program that writes to a log file when an error occurs during file handling.**
#
# **Answer:**
#
# This combines file handling with logging for error reporting.

# %%
import logging
import os

# Define the name of the log file for errors
LOG_FILE_NAME = "file_handling_errors.log"

# --- Logging Configuration ---
# It's good practice to ensure a clean log file for demonstration,
# so we'll remove it if it exists from a previous run.
if os.path.exists(LOG_FILE_NAME):
    try:
        os.remove(LOG_FILE_NAME)
        print(f"Cleaned up previous log file: {LOG_FILE_NAME}")
    except OSError as e:
        print(f"Error removing old log file {LOG_FILE_NAME}: {e}")

# Configure the logging system
# - filename: Specifies the file to which logs will be written.
# - level: Sets the minimum logging level to capture. Here, only messages
#          of level ERROR and higher (CRITICAL) will be written to the file.
# - format: Defines the layout of the log messages.
#   - %(asctime)s: Current time when the log record was created.
#   - %(levelname)s: The text logging level for the message (e.g., ERROR).
#   - %(module)s: The name of the module where the log call was made.
#   - %(lineno)d: The line number where the log call was made.
#   - %(message)s: The actual log message.
logging.basicConfig(
    filename=LOG_FILE_NAME,
    level=logging.ERROR, # Only log ERROR and CRITICAL messages to the file
    format='%(asctime)s - %(levelname)s - %(module)s:%(lineno)d - %(message)s'
)

# Get a logger instance. It's good practice to get a named logger.
logger = logging.getLogger('file_handler_app')

# --- Function to perform safe file reading ---
def safe_file_read(filename):
    """
    Attempts to read the content of a file.
    Logs an error message to LOG_FILE_NAME if any file handling error occurs.

    Args:
        filename (str): The path to the file to be read.
    """
    print(f"\nAttempting to read file: '{filename}'")
    try:
        with open(filename, "r") as file:
            content = file.read()
            print(f"Successfully read '{filename}'. Content length: {len(content)} characters.")
            # Optionally log success, but won't go to file with ERROR level
            logger.info(f"Successfully read file: {filename}")
    except FileNotFoundError:
        # Log a specific error for files that do not exist
        error_msg = f"File not found: The file '{filename}' does not exist."
        logger.error(error_msg, exc_info=True) # exc_info=True adds the traceback
        print(f"Operation failed: {error_msg}. Check '{LOG_FILE_NAME}' for details.")
    except PermissionError:
        # Log a specific error for permission issues
        error_msg = f"Permission denied: You do not have sufficient permissions to read '{filename}'."
        logger.error(error_msg, exc_info=True)
        print(f"Operation failed: {error_msg}. Check '{LOG_FILE_NAME}' for details.")
    except IOError as e:
        # Catch other general I/O errors (e.g., disk full, corrupted file)
        error_msg = f"An I/O error occurred while reading '{filename}': {e}"
        logger.error(error_msg, exc_info=True)
        print(f"Operation failed: {error_msg}. Check '{LOG_FILE_NAME}' for details.")
    except Exception as e:
        # Catch any other unexpected exceptions as critical
        error_msg = f"An unexpected critical error occurred during file operation on '{filename}': {type(e).__name__} - {e}"
        logger.critical(error_msg, exc_info=True)
        print(f"Operation failed: {error_msg}. Check '{LOG_FILE_NAME}' for details.")

# --- Test Cases ---

# Test Case 1: Reading an existing file (success)
existing_file = "my_document.txt"
with open(existing_file, "w") as f:
    f.write("This is a sample document for testing file reading.")
safe_file_read(existing_file)

# Test Case 2: Reading a non-existent file (FileNotFoundError)
non_existent_file = "non_existent_document.txt"
safe_file_read(non_existent_file)

# Test Case 3: Simulating a PermissionError (platform-dependent)
# On Unix-like systems (Linux, macOS), you can create a file and remove read permissions.
# On Windows, simulating this directly in Python is harder without admin rights or specific file locks.
# For demonstration, we'll create a dummy file and try to set permissions,
# but the actual PermissionError might not occur depending on your OS and user privileges.
permission_denied_file = "restricted_access.txt"
try:
    with open(permission_denied_file, "w") as f:
        f.write("This file has restricted access.")
    # Attempt to change permissions to be unreadable for others (or current user)
    # This might require specific OS capabilities or admin rights.
    # For a general demo, this might not always trigger PermissionError.
    # On Linux/macOS, 0o000 means no permissions for anyone.
    os.chmod(permission_denied_file, 0o000)
    safe_file_read(permission_denied_file)
except OSError as e:
    print(f"\nCould not set permissions for '{permission_denied_file}' to test PermissionError: {e}")
    print("Skipping PermissionError test as OS did not allow permission change.")
finally:
    # Clean up the restricted file
    if os.path.exists(permission_denied_file):
        os.remove(permission_denied_file)


print(f"\nProgram finished. Check the file '{LOG_FILE_NAME}' for detailed error logs.")
# Out:
# ERROR:file_handler_app:File not found: The file 'non_existent_document.txt' does not exist.
# Traceback (most recent call last):
#   File "/tmp/ipython-input-510298512.py", line 47, in safe_file_read
#     with open(filename, "r") as file:
#          ^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'non_existent_document.txt'
# Attempting to read file: 'my_document.txt'
# Successfully read 'my_document.txt'. Content length: 51 characters.
#
# Attempting to read file: 'non_existent_document.txt'
# Operation failed: File not found: The file 'non_existent_document.txt' does not exist.. Check 'file_handling_errors.log' for details.
#
# Attempting to read file: 'restricted_access.txt'
# Successfully read 'restricted_access.txt'. Content length: 32 characters.
#
# Program finished. Check the file 'file_handling_errors.log' for detailed error logs.
